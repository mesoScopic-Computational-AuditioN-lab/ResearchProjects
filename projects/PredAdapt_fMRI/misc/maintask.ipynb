# %%
import scipy.io
import pandas as pd
import numpy as np
import re

import matplotlib.pyplot as plt

# %%
def find_onoff(pulsez_df, currun, tr=1.8, volumes=245):
    # load important info
    ab_t0 = pulsez_df['timing'][pulsez_df['run']==currun].iloc[0]  # this is for run 1
    ab_end = pulsez_df['timing'][pulsez_df['run']==currun].iloc[-1]  # this is for run 1
    
    # set range
    pulserangerun = np.linspace(ab_t0, ab_end, num=volumes, retstep=False)
    ontimes = pulsez_df['timing'][pulsez_df['run']==currun].to_numpy()
    
    # get off times
    offtimes = np.abs(pulserangerun[:,None]-ontimes).argmin(0) # get on times
    onoff = np.ones(volumes)
    onoff[offtimes] = 0 # set off times to 0
    
    return(pulserangerun, onoff)



def find_block(pulsez_df, currun, tr=1.8, volumes=245):
    # load important info
    ab_t0 = pulsez_df['timing'][pulsez_df['run']==currun].iloc[0]  # this is for run 1
    ab_end = pulsez_df['timing'][pulsez_df['run']==currun].iloc[-1]  # this is for run 1
    blocks = pulsez_df['block'][pulsez_df['run']==currun].to_numpy()
    
    # set range
    pulserangerun = np.linspace(ab_t0, ab_end, num=volumes, retstep=False)
    ontimes = pulsez_df['timing'][pulsez_df['run']==currun].to_numpy()

    # get off times
    offtimes = np.abs(pulserangerun[:,None]-ontimes).argmin(0) # get on times
    allblocks = np.empty(volumes)
    allblocks[:] = np.nan
    
    allblocks[offtimes] = blocks # set off times to 0
    allblocks = ffill(allblocks) # forward fill the array
    
    return(allblocks)

def closest_vol(volumes_df, timingz):
    a = volumes_df['timing'].to_numpy()
    b = timingz

    # get volume
    seq_vol = np.abs(a[:,None]-b).argmin(0)
    rel_vol = seq_vol - (runz-1)*float(len(volumes_df[volumes_df['run'] == 1]))
    return(seq_vol, rel_vol.astype(int))

def closest_vol_floor(volumes_df, timingz):
    a = volumes_df['timing'].to_numpy()
    b = timingz

    # get volume
    dist = (a[:,None]-b) # get the distance
    dist[dist < 0.05] = 999 # get rid of pos distancane (- some window)
    seq_vol = np.abs(dist).argmin(0)
    rel_vol = seq_vol - (runz-1)*float(len(volumes_df[volumes_df['run'] == 1]))
    return(seq_vol, rel_vol.astype(int))

def closest_vol_timing(volumes_df, timingz):
    a = volumes_df['timing'].to_numpy()
    b = timingz

    # get volume
    seq_vol = np.abs(a[:,None]-b).argmin(0)
    rel_vol = seq_vol - (runz-1)*float(len(volumes_df[volumes_df['run'] == 1]))
    return(seq_vol, rel_vol)

def ffill(arr, axis=0):
    idx_shape = tuple([slice(None)] + [np.newaxis] * (len(arr.shape) - axis - 1))
    idx = np.where(~np.isnan(arr), np.arange(arr.shape[axis])[idx_shape], 0)
    np.maximum.accumulate(idx, axis=axis, out=idx)
    slc = [np.arange(k)[tuple([slice(None) if dim==i else np.newaxis
        for dim in range(len(arr.shape))])]
        for i, k in enumerate(arr.shape)]
    slc[axis] = idx
    return arr[tuple(slc)]

def flatten(d):
    return(pd.json_normalize(d, sep='_').to_dict(orient='records')[0])

# %% [markdown]
# ## load the actual information

# %%
pp = 2
mat = scipy.io.loadmat('/media/jorvhar/Data/MRIData/timing data/data/{}/{}-mainpred.mat'.format(pp, pp))
stimuli = scipy.io.loadmat('/media/jorvhar/Data/MRIData/timing data/stimuli/{}/{}_main_stims.mat'.format(pp, pp))

# %% [markdown]
# ## Quickly check the data

# %%
blocknr = 1
idxblock = np.where(mat['timingz'][1] == blocknr) # where block is 1

#get frequency presentation data for block
frequencies = stimuli['pres_freq'][blocknr-1, :]

# other values
tps = np.sum(mat['timingz'][3, idxblock] == 1) # get trials per secion

#get timings back from mat file, substract begin time
timings = mat['timingz'][4, idxblock] - np.min(mat['timingz'][4, idxblock]) 

matidx = np.where(mat['segmentz'][1] == blocknr)

centa = 2**np.repeat(mat['segmentz'][7][matidx], tps)   # cent freq a
centb = 2**np.repeat(mat['segmentz'][8][matidx], tps)  # cent freq b
proba = np.repeat(mat['segmentz'][5][matidx], tps)  # prob a
probb = np.repeat(mat['segmentz'][6][matidx], tps)  # prob b

# %%
# senatry check the data
fig, ax = plt.subplots(2, 1, gridspec_kw={'height_ratios': [3, 1]}, figsize=(12, 8))

ax[0].scatter(timings, frequencies)
ax[0].axhline(y=centa[0], color='r', linestyle='-')
ax[0].axhline(y=centb[0], color='g', linestyle='-')

ax[1].plot(proba, color='r')
ax[1].plot(probb, color='g')

# %% [markdown]
# ##  Put information of pulsez into a pandas dataframe

# %%
nr_runs = 12

# set empty array to concatenate pulse fetched data
allpulsez = 0

# loop over runs and parse data
for currun in np.arange(1,nr_runs+1):
    pulsez = scipy.io.loadmat('/media/jorvhar/Data/MRIData/timing data/data/{}/_{}-r{}-pulses.mat'.format(pp, pp, currun))['pulsez']
    pulsez = np.vstack([np.repeat(currun, pulsez.shape[1]), pulsez])
    try:
        allpulsez = np.concatenate((allpulsez,pulsez),axis=1)
    except:
        allpulsez = pulsez
        
# put in dataframe
pulsez_df = pd.DataFrame(np.transpose(allpulsez), columns=['run', 'block', 'timing'])
pulsez_df
# Out:
#       run  block         timing
# 0     1.0    1.0  607354.205883
# 1     1.0    1.0  607356.006130
# 2     1.0    1.0  607357.805883
# 3     1.0    1.0  607359.606107
# 4     1.0    1.0  607361.406175
# ..    ...    ...            ...
# 523  12.0   36.0  613531.307240
# 524  12.0   36.0  613533.107246
# 525  12.0   36.0  613534.907253
# 526  12.0   36.0  613536.707040
# 527  12.0   36.0  613538.507233
#
# [528 rows x 3 columns]

# %% [markdown]
# ### Use the raw pulse information to get volume level information

# %%
# settings
tr = 1.8
volumes = 245

# precreate dicts
tm = {}
onoff = {}
block = {}

# loop over all the runs
for currun in np.arange(1, nr_runs+1):
    tm[currun], onoff[currun] = find_onoff(pulsez_df, currun, tr=tr, volumes=volumes)
    block[currun] = find_block(pulsez_df, 1, tr=1.8, volumes=245)

# %%
# append to one full array
tmz = np.array([])
onoffz = np.array([])
runz = np.array([])
blockz = np.array([])

# loop over runs and fill
for currun in tm.keys():
    tmz = np.append(tmz, tm[currun])
    onoffz = np.append(onoffz, onoff[currun]) 
    runz = np.append(runz, np.array([currun] * len(tm[currun])))
    blockz = np.append(blockz, block[currun]) 
    
# put everything in a pandas dataframe
df_inf = {'timing':tmz, 'run':runz, 'block':blockz, 'on-times':onoffz}
volumes_df = pd.DataFrame(df_inf)

# %% [markdown]
# #### Add other information de dataframe if desired

# %%
volumes_df = volumes_df.assign(adapt = 0)
volumes_df = volumes_df.assign(pred = 0)
volumes_df.head(12)
# Out:
#            timing  run  block  on-times  adapt  pred
# 0   607354.205883  1.0    1.0       0.0      0     0
# 1   607356.005910  1.0    1.0       0.0      0     0
# 2   607357.805936  1.0    1.0       0.0      0     0
# 3   607359.605962  1.0    1.0       0.0      0     0
# 4   607361.405988  1.0    1.0       0.0      0     0
# 5   607363.206014  1.0    1.0       1.0      0     0
# 6   607365.006040  1.0    1.0       1.0      0     0
# 7   607366.806066  1.0    1.0       1.0      0     0
# 8   607368.606092  1.0    1.0       1.0      0     0
# 9   607370.406118  1.0    1.0       1.0      0     0
# 10  607372.206145  1.0    1.0       1.0      0     0
# 11  607374.006171  1.0    1.0       1.0      0     0

# %% [markdown]
# ## get trial level dataframe

# %%
# set arrays
freqz   = np.array([])
timingz  = np.array([])
runz     = np.array([])
blockz   = np.array([])
segmenz  = np.array([])
centaz   = np.array([])
centbz   = np.array([])
probaz   = np.array([])
probbz   = np.array([])

for blk in np.arange(1, pulsez_df['block'].max()+1):
    # get blockidx
    idxblock = np.where(mat['timingz'][1] == blk) # where block is 1

    #get frequency presentation data for block
    frequencies = stimuli['pres_freq'][int(blk)-1, :]
    
    # other values
    tps = np.sum(mat['timingz'][3, idxblock] == 1) # get trials per secion
    
    #get timings back from mat file, substract begin time
    timings = mat['timingz'][4, idxblock]
    matidx = np.where(mat['segmentz'][1] == blk)
    
    # append to arrays
    freqz = np.append(freqz, frequencies)
    timingz = np.append(timingz, timings)
    runz = np.append(runz, np.repeat(mat['segmentz'][0][matidx], tps))
    blockz = np.append(blockz, np.repeat(mat['segmentz'][1][matidx], tps))
    segmenz = np.append(segmenz, np.repeat(mat['segmentz'][2][matidx], tps))
    centaz = np.append(centaz, 2**np.repeat(mat['segmentz'][7][matidx], tps))   # cent freq a
    centbz = np.append(centbz, 2**np.repeat(mat['segmentz'][8][matidx], tps))  # cent freq b
    probaz = np.append(probaz, np.repeat(mat['segmentz'][5][matidx], tps))
    probbz = np.append(probbz, np.repeat(mat['segmentz'][6][matidx], tps))
    
# oct variant 
freqz_oct = np.log2(freqz)
centaz_oct = np.log2(centaz)
centbz_oct = np.log2(centbz)

# get closest pulse
vol_absz, vol_relz = closest_vol(volumes_df, timingz)
vol_abs_flrz, vol_rel_flrz = closest_vol_floor(volumes_df, timingz)

# %%
# put data into a dictionary and subsequentially in a dataframe
stim_df_dict = {'frequencies': freqz,
                'frequencies_oct': freqz_oct,
                'timing': timingz,
                'closest_volume_rel' : vol_relz,
                'closest_volume_abs' : vol_absz,
                'volume_rel' : vol_rel_flrz,
                'volume_abs' : vol_abs_flrz,
                'run': runz,
                'block': blockz,
                'segment': segmenz,
                'center_freq_a': centaz,
                'center_freq_b': centbz,
                'center_freq_a_oct': centaz_oct,
                'center_freq_b_oct': centbz_oct,
                'probability_a': probaz,
                'probability_b': probbz
               }

stim_df = pd.DataFrame(stim_df_dict)

# %%
stim_df
# Out:
#        frequencies  frequencies_oct         timing  closest_volume_rel  \
# 0      2896.309376        11.500000  607363.205175                   5
# 1      2896.309376        11.500000  607363.455175                   5
# 2       966.527296         9.916667  607363.705175                   5
# 3       912.280287         9.833333  607363.955175                   5
# 4      2298.802275        11.166667  607364.205175                   6
# ...            ...              ...            ...                 ...
# 17275   767.133223         9.583333  613497.053499                 221
# 17276  2169.780417        11.083333  613497.303499                 221
# 17277  1024.000000        10.000000  613497.553499                 221
# 17278   645.079578         9.333333  613497.803499                 221
# 17279  2048.000000        11.000000  613498.053499                 222
#
#        closest_volume_abs  volume_rel  volume_abs   run  block  segment  \
# 0                       5           6           6   1.0    1.0      1.0
# 1                       5           6           6   1.0    1.0      1.0
# 2                       5           6           6   1.0    1.0      1.0
# 3                       5           6           6   1.0    1.0      1.0
# 4                       6           6           6   1.0    1.0      1.0
# ...                   ...         ...         ...   ...    ...      ...
# 17275                2916         221        2916  12.0   36.0     10.0
# 17276                2916         222        2917  12.0   36.0     10.0
# 17277                2916         222        2917  12.0   36.0     10.0
# 17278                2916         222        2917  12.0   36.0     10.0
# 17279                2917         222        2917  12.0   36.0     10.0
#
#        center_freq_a  center_freq_b  center_freq_a_oct  center_freq_b_oct  \
# 0        1077.614428     3000.00000          10.073625          11.550747
# 1        1077.614428     3000.00000          10.073625          11.550747
# 2        1077.614428     3000.00000          10.073625          11.550747
# 3        1077.614428     3000.00000          10.073625          11.550747
# 4        1077.614428     3000.00000          10.073625          11.550747
# ...              ...            ...                ...                ...
# 17275     834.255221     2322.50571           9.704345          11.181466
# 17276     834.255221     2322.50571           9.704345          11.181466
# 17277     834.255221     2322.50571           9.704345          11.181466
# 17278     834.255221     2322.50571           9.704345          11.181466
# 17279     834.255221     2322.50571           9.704345          11.181466
#
#        probability_a  probability_b
# 0           0.603635       0.396365
# 1           0.603635       0.396365
# 2           0.603635       0.396365
# 3           0.603635       0.396365
# 4           0.603635       0.396365
# ...              ...            ...
# 17275       0.891211       0.108789
# 17276       0.891211       0.108789
# 17277       0.891211       0.108789
# 17278       0.891211       0.108789
# 17279       0.891211       0.108789
#
# [17280 rows x 16 columns]

# %% [markdown]
# ## measures of adaptation and prediction

# %%
import HGF

# import fit and sim models from the hgf
from HGF import hgf_fit
from HGF import hgf_sim

# import the presentation functions for plotting and storing
from HGF import hgf_pres

# load our configuration functions
from HGF.hgf_config import *
from HGF.hgf import *

# %%
import Adaptation.longtrace_adaptation as longtrace_adaptation
import Adaptation.longtrace_adaptation_timedomain as longtrace_adaptation_timedomain
# Out:
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/nilearn/glm/__init__.py:55: FutureWarning: The nilearn.glm module is experimental. It may change in any future release of Nilearn.
#   warn('The nilearn.glm module is experimental. '

# %%
import Sequence_correlations

# %%
# settings
mat = scipy.io.loadmat('/media/jorvhar/Data/MRIData/timing data/data/{}/{}_settings_tonotopy.mat'.format(pp, pp))
all_freqs = mat['cfg']['freq_array'][0][0][0,:]

tunsteps       = 10
freqstep       = 1
fwhm           = np.linspace(25,(100), tunsteps)[::-1]
subsample      = np.arange(0,len(all_freqs), freqstep)
mustep         = np.diff(all_freqs[subsample])
sigmagrid      = np.log(2) / (mustep[0]* fwhm/2) **2
octgrid        = np.log2(np.exp(1) * fwhm * mustep[0])
muarray_bins   = all_freqs
muarray        = all_freqs[subsample]

# %%
octgrid
# Out:
# array([2.48049353, 2.35496265, 2.21745912, 2.06545603, 1.89553103,
#        1.70288595, 1.48049353, 1.21745912, 0.89553103, 0.48049353])

# %%
# for now overwrite and only take tw of 1.2
octgrid = np.array([1.2])

# %%
# loop over blocks
for blk in stim_df['block'].unique():
    blk

# %% [markdown]
# ### adaptation

# %%
# set range of tunings and sharpnesses
pref_range  = muarray                # match t
sharp_range = octgrid

# %%
# for now take values from paper [change later!]
x_decay, y_decay = longtrace_adaptation.double_exp_decay_func(0.1399, 0.85, 0.0345, 6.82, [1, 10], 1)

# set range of tunings and sharpnesses
pref_range  = muarray                # match t
sharp_range = octgrid

# %%
adapt_dict = {}
act_dict = {}
adp_act_dict = {}
adapt_dict_flat = {}
act_dict_flat = {}
adp_act_dict_flat = {}

for blk in stim_df['block'].unique():
    stims = stim_df['frequencies_oct'][stim_df['block'] == blk].to_numpy()

    # get dictionary
    adapt_dict[blk] = longtrace_adaptation.create_adaptation_dict(stims, y_decay, pref_range, sharp_range)

    # for raw activations
    act_dict[blk] = longtrace_adaptation.create_activation_dict(stims, pref_range, sharp_range)

    # calculate the adapted weighted activation dictionary
    adp_act_dict[blk] = longtrace_adaptation.create_adapted_activation_dict(act_dict[blk], adapt_dict[blk])

    # flatten
    adapt_dict_flat[blk] = flatten(adapt_dict[blk])
    act_dict_flat[blk] = flatten(act_dict[blk])
    adp_act_dict_flat[blk] = flatten(adp_act_dict[blk])
    
    # add prefix
    adapt_dict_flat[blk] = {f'adapt_{k}': v for k, v in adapt_dict[blk].items()}
    act_dict_flat[blk] = {f'acti_{k}': v for k, v in act_dict[blk].items()}
    adp_act_dict_flat[blk] = {f'adaptact_{k}': v for k, v in adp_act_dict[blk].items()}

# %%
# put in dataframe
adaptdict = pd.DataFrame()

for k in adapt_dict.keys():
    
    
    
    tempdict = pd.DataFrame({**adapt_dict_flat[blk], **act_dict_flat[blk], **adp_act_dict_flat[blk]})
    tempdict = tempdict.assign(block=k)
    
    adaptdict = pd.concat([adaptdict, tempdict], ignore_index=True)

# %%
adapt_dict_flat[8]['adapt_7.643856189774724']
# Out:
# {2.480493528013555: array([1.        , 0.8924721 , 0.80423789, 0.82956829, 0.8280561 ,
#         0.7792386 , 0.75506233, 0.757836  , 0.74257925, 0.7969555 ,
#         0.79280938, 0.72370073, 0.78541547, 0.78875839, 0.8031727 ,
#         0.73696214, 0.77869702, 0.78671436, 0.79714664, 0.80266599,
#         0.7903832 , 0.72882998, 0.7569403 , 0.71589173, 0.73544696,
#         0.7545918 , 0.72174525, 0.75286809, 0.70402627, 0.75855195,
#         0.76666639, 0.74662025, 0.73373992, 0.76258259, 0.77570993,
plt.plot(act_dict[list(act_dict.keys())[6]][list(act_dict[list(act_dict.keys())[6]].keys())[8]][1.2])
plt.plot(adp_act_dict[list(adp_act_dict.keys())[6]][list(adp_act_dict[list(adp_act_dict.keys())[6]].keys())[8]][1.2])
plt.plot(adapt_dict[list(adapt_dict.keys())[6]][list(adapt_dict[list(adapt_dict.keys())[6]].keys())[8]][1.2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [29], in <cell line: 3>()
#       1 adapt_dict.keys(), adapt_dict[list(adapt_dict.keys())[0]].keys()
# ----> 3 plt.plot(act_dict[list(act_dict.keys())[6]][list(act_dict[list(act_dict.keys())[6]].keys())[8]][1.2])
#       4 plt.plot(adp_act_dict[list(adp_act_dict.keys())[6]][list(adp_act_dict[list(adp_act_dict.keys())[6]].keys())[8]][1.2])
#       5 plt.plot(adapt_dict[list(adapt_dict.keys())[6]][list(adapt_dict[list(adapt_dict.keys())[6]].keys())[8]][1.2])
#
# KeyError: 1.2

# %%
adaptdict.keys
# Out:
#                               adapt_7.643856189774724  \
# 0   [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 1   [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 2   [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 3   [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 4   [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 5   [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 6   [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 7   [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 8   [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 9   [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 10  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 11  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 12  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 13  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 14  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 15  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 16  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 17  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 18  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 19  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 20  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 21  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 22  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 23  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 24  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 25  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 26  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 27  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 28  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 29  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 30  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 31  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 32  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 33  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 34  [1.0, 0.9626202661516814, 0.942902793752834, 0...
# 35  [1.0, 0.9626202661516814, 0.942902793752834, 0...
#
#                               adapt_7.664387112768902  \
# 0   [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 1   [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 2   [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 3   [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 4   [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 5   [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 6   [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 7   [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 8   [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 9   [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 10  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 11  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 12  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 13  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 14  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 15  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 16  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 17  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 18  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 19  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 20  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 21  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 22  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 23  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 24  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 25  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 26  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 27  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 28  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 29  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 30  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 31  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 32  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 33  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 34  [1.0, 0.9614864223093507, 0.9412421428518216, ...
# 35  [1.0, 0.9614864223093507, 0.9412421428518216, ...
#
#                                adapt_7.68491803576308  \
# 0   [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 1   [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 2   [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 3   [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 4   [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 5   [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 6   [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 7   [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 8   [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 9   [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 10  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 11  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 12  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 13  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 14  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 15  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 16  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 17  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 18  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 19  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 20  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 21  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 22  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 23  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 24  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 25  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 26  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 27  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 28  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 29  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 30  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 31  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 32  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 33  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 34  [1.0, 0.9603297994649507, 0.9395512913784063, ...
# 35  [1.0, 0.9603297994649507, 0.9395512913784063, ...
#
#                               adapt_7.705448958757258  \
# 0   [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 1   [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 2   [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 3   [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 4   [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 5   [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 6   [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 7   [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 8   [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 9   [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 10  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 11  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 12  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 13  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 14  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 15  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 16  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 17  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 18  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 19  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 20  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 21  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 22  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 23  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 24  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 25  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 26  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 27  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 28  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 29  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 30  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 31  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 32  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 33  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 34  [1.0, 0.9591504007331365, 0.9378303969831812, ...
# 35  [1.0, 0.9591504007331365, 0.9378303969831812, ...
#
#                               adapt_7.725979881751436  \
# 0   [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 1   [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 2   [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 3   [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 4   [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 5   [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 6   [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 7   [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 8   [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 9   [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 10  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 11  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 12  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 13  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 14  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 15  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 16  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 17  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 18  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 19  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 20  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 21  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 22  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 23  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 24  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 25  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 26  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 27  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 28  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 29  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 30  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 31  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 32  [1.0, 0.9579482496164619, 0.9360796487915728, ...
# 33  [1.0, 0.9579482496164619, 0.9360796487915728, ...
#
# 25  [0.06563314191081238, 0.0550409154954658, 0.78...  26.0
# 26  [0.06563314191081238, 0.0550409154954658, 0.78...  27.0
# 27  [0.06563314191081238, 0.0550409154954658, 0.78...  28.0
# 28  [0.06563314191081238, 0.0550409154954658, 0.78...  29.0
# 29  [0.06563314191081238, 0.0550409154954658, 0.78...  30.0
# 30  [0.06563314191081238, 0.0550409154954658, 0.78...  31.0
# 31  [0.06563314191081238, 0.0550409154954658, 0.78...  32.0
# 32  [0.06563314191081238, 0.0550409154954658, 0.78...  33.0
# 33  [0.06563314191081238, 0.0550409154954658, 0.78...  34.0
# 34  [0.06563314191081238, 0.0550409154954658, 0.78...  35.0
# 35  [0.06563314191081238, 0.0550409154954658, 0.78...  36.0
#
# [36 rows x 721 columns]

# %%
adaptdict[adaptdict['block'].isin(blocks)].filter(regex=("adapt_.*")).T
# Out:
#                                                                           4
# adapt_7.643856189774724   [1.0, 0.9626202661516814, 0.942902793752834, 0...
# adapt_7.664387112768902   [1.0, 0.9614864223093507, 0.9412421428518216, ...
# adapt_7.68491803576308    [1.0, 0.9603297994649507, 0.9395512913784063, ...
# adapt_7.705448958757258   [1.0, 0.9591504007331365, 0.9378303969831812, ...
# adapt_7.725979881751436   [1.0, 0.9579482496164619, 0.9360796487915728, ...
# ...                                                                     ...
# adapt_12.468623093406531  [1.0, 0.9866025714690979, 0.983041589314076, 0...
# adapt_12.489154016400711  [1.0, 0.9871138199105375, 0.9836993492213104, ...
# adapt_12.509684939394887  [1.0, 0.987609186600439, 0.9843362498149113, 0...
# adapt_12.530215862389065  [1.0, 0.9880889976673486, 0.9849527337371032, ...
# adapt_12.550746785383243  [1.0, 0.9885535800507543, 0.9855492442797998, ...
#
# [240 rows x 1 columns]

# %%
import seaborn as sns

blocks = [5]

f, ax = plt.subplots(figsize=(15, 15))

ax = sns.heatmap(adaptdict[adaptdict['block'].isin(blocks)].filter(regex=("adapt_.*")).T, cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [53], in <cell line: 7>()
#       3 blocks = [5]
#       5 f, ax = plt.subplots(figsize=(15, 15))
# ----> 7 ax = sns.heatmap(adaptdict[adaptdict['block'].isin(blocks)].filter(regex=("adapt_.*")).T)
#
# File ~/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/seaborn/matrix.py:540, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     362 """Plot rectangular data as a color-encoded matrix.
#     363
#     364 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     537     ...     ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True)
#     538 """
#     539 # Initialize the plotter object
# --> 540 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     541                       annot_kws, cbar, cbar_kws, xticklabels,
#     542                       yticklabels, mask)
#     544 # Add the pcolormesh kwargs here
#     545 kwargs["linewidths"] = linewidths
#
# File ~/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/seaborn/matrix.py:159, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     156 self.ylabel = ylabel if ylabel is not None else ""
#     158 # Determine good default values for the colormapping
# --> 159 self._determine_cmap_params(plot_data, vmin, vmax,
#     160                             cmap, center, robust)
#     162 # Sort out the annotations
#     163 if annot is None or annot is False:
#
# File ~/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/seaborn/matrix.py:193, in _HeatMapper._determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     190 """Use some heuristics to set good defaults for colorbar and range."""
#     192 # plot_data is a np.ma.array instance
# --> 193 calc_data = plot_data.astype(float).filled(np.nan)
#     194 if vmin is None:
#     195     if robust:
#
# ValueError: setting an array element with a sequence.

# %% [markdown]
# ## translate to adaptation + predictions by hrf + tw + sigma

# %%
# create dict with our settings
c = {}
c['c_prc'] = {}

# set our number of levels
c['c_prc']['n_levels']   = 3

# define the priors for all levels
c['c_prc']['mu_0mu'] = np.array([99991, 1, 1])
c['c_prc']['mu_0sa'] = np.array([99992, 0, 0])
c['c_prc']['logsa_0mu'] = np.array([99993, np.log(0.1), np.log(0.1)])
c['c_prc']['logsa_0sa'] = np.array([1, 1, 1])

c['c_prc']['rhomu'] = np.array([0, 0, 0])
c['c_prc']['rhosa'] = np.array([0, 0, 0])
c['c_prc']['logkamu'] = np.array([np.log(1), np.log(1)])
c['c_prc']['logkasa'] = np.array([0, 0])

c['c_prc']['ommu'] = np.array([99993, -4, -8])
c['c_prc']['omsa'] = np.array([4**2, 4**2, 4**2])
c['c_prc']['logpiumu'] = np.array([-99993])
c['c_prc']['logpiusa'] = np.array([2**2])

# gather prior settings in vectors
c['c_prc']['priormus'] = np.concatenate([c['c_prc']['mu_0mu'], 
                                        c['c_prc']['logsa_0mu'], 
                                        c['c_prc']['rhomu'], 
                                        c['c_prc']['logkamu'], 
                                        c['c_prc']['ommu'], 
                                        c['c_prc']['logpiumu']], axis=0)
c['c_prc']['priorsas'] = np.concatenate([c['c_prc']['mu_0sa'], 
                                        c['c_prc']['logsa_0sa'], 
                                        c['c_prc']['rhosa'], 
                                        c['c_prc']['logkasa'], 
                                        c['c_prc']['omsa'], 
                                        c['c_prc']['logpiusa']], axis=0)

# %%
range_model = gaussian_obs_range_config
range_model = bayes_optimal_range_config

# %%
# import Sequence_correlations

# surp_dict            = Sequence_correlations.create_surprisal_dict(pref_range, r, normalize=False)
# prob_dict            = Sequence_correlations.create_probability_dict(surp_dict)

# %%
surp_dict = {}
prob_dict = {}
surp_dict_flat = {}
prob_dict_flat = {}

for blk in stim_df['block'].unique():
    
    # do HGFing
    stims = stim_df['frequencies_oct'][stim_df['block'] == blk].to_numpy()

    sim = hgf_sim.simModel(stims, hgf, 
                           np.array([10, 0.1, 1.0, 0.001, -0.001,
                                     -0.1, 0, 0, 0,
                                     0.08, 0.12, 0.12,
                                     3.6, 0.5, 2.5]) ,
                           obs_model=gaussian_obs,
                           obs_pvec=0.00002)

    r = hgf_fit.fitModel(sim['y'],
                         stims,
                         ehgf_config,
                         bayes_optimal_config, 
                         quasinewton_optim_config,
                         obs_range_model=range_model,
                         obs_range_u=pref_range,
                         overwrite_opt=c)

    
    surp_dict[blk]            = Sequence_correlations.create_surprisal_dict(pref_range, r, normalize=False)
    prob_dict[blk]            = Sequence_correlations.create_probability_dict(surp_dict[blk])
    
    # add prefix
    surp_dict_flat[blk] = {f'surp_{k}': v for k, v in surp_dict[blk].items()}
    prob_dict_flat[blk] = {f'prob_{k}': v for k, v in prob_dict[blk].items()}
# Out:
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 494.816803
#          Iterations: 28
#          Function evaluations: 324
#          Gradient evaluations: 36
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [10.79841272  1.          1.        ]
#  sa_0: 	 [0.50143953 0.07607533 0.10000008]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.34005958 -8.89810616]
#  th: 	 0.00033561642678241947
#  pi_u: 	 0.45351320940881196
#  al: 	 2.2050074380492113
#
# MODEL QUALITY:
#  LME: 	 -495.06290448690066 		 (more is better)
#  AIC: 	 980.0617623577018 		 (less is better)
#  BIC: 	 981.1675877377844 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 538.033491
#          Iterations: 38
#          Function evaluations: 387
#          Gradient evaluations: 43
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [10.60635569  1.          1.        ]
#  sa_0: 	 [0.60117472 0.09111509 0.10000549]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.4044334  -8.64438369]
#  th: 	 0.0003356420189581263
#  pi_u: 	 0.2990781049190541
#  al: 	 3.3436081864657106
#
# MODEL QUALITY:
#  LME: 	 -538.5405477866844 		 (more is better)
#  AIC: 	 1065.5481522400942 		 (less is better)
#  BIC: 	 1066.650782873878 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 512.340347
#          Iterations: 34
#          Function evaluations: 342
#          Gradient evaluations: 38
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [10.24757966  1.          1.        ]
#  sa_0: 	 [0.1124956  0.05297101 0.10000184]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.80295645 -9.94815074]
#  th: 	 0.0003353899435143246
#  pi_u: 	 0.2781274377541016
#  al: 	 3.595474103795978
#
# MODEL QUALITY:
#  LME: 	 -512.592897031177 		 (more is better)
#  AIC: 	 1013.8537686385905 		 (less is better)
#  BIC: 	 1014.9730291315597 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:320: RuntimeWarning: overflow encountered in exp
#   vv = t[trial] * np.exp(p_dict['ka'][lvl-1]*
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:324: RuntimeWarning: invalid value encountered in double_scalars
#   ww = vv * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:325: RuntimeWarning: invalid value encountered in double_scalars
#   rr = (vv - pi[trial-1, lvl-1]**-1) * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:291: RuntimeWarning: overflow encountered in exp
#   * np.exp(p_dict['ka'][lvl] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:315: RuntimeWarning: invalid value encountered in double_scalars
#   0.5 * pi_hat[trial,lvl]**-1 * \
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:307: RuntimeWarning: overflow encountered in exp
#   v[trial,l-2] = t[trial] * np.exp(p_dict['ka'][l-2] * mu[trial-1, l-1] + p_dict['om'][l-2])
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:308: RuntimeWarning: invalid value encountered in double_scalars
#   w[trial,l-2] = v[trial,l-2] * pi_hat[trial,l-2]
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:274: RuntimeWarning: invalid value encountered in double_scalars
#   mu[trial,0] = mu_hat[trial, 0] + pi_hat[trial, 0]**-1 * \
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   w[trial, lvl-1] = v[trial, lvl-1] * pi_hat[trial, lvl-1]
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/scipy/optimize/_numdiff.py:576: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:320: RuntimeWarning: overflow encountered in exp
#   vv = t[trial] * np.exp(p_dict['ka'][lvl-1]*
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:324: RuntimeWarning: invalid value encountered in double_scalars
#   ww = vv * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:325: RuntimeWarning: invalid value encountered in double_scalars
#   rr = (vv - pi[trial-1, lvl-1]**-1) * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:291: RuntimeWarning: overflow encountered in exp
#   * np.exp(p_dict['ka'][lvl] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:315: RuntimeWarning: invalid value encountered in double_scalars
#   0.5 * pi_hat[trial,lvl]**-1 * \
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:307: RuntimeWarning: overflow encountered in exp
#   v[trial,l-2] = t[trial] * np.exp(p_dict['ka'][l-2] * mu[trial-1, l-1] + p_dict['om'][l-2])
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:308: RuntimeWarning: invalid value encountered in double_scalars
#   w[trial,l-2] = v[trial,l-2] * pi_hat[trial,l-2]
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:344: RuntimeWarning: invalid value encountered in double_scalars
#   da[trial,lvl] = (pi[trial,lvl]**-1 + (mu[trial,lvl] - mu_hat[trial, lvl])**2)  *  pi_hat[trial,lvl] -1
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:344: RuntimeWarning: overflow encountered in double_scalars
#   da[trial,lvl] = (pi[trial,lvl]**-1 + (mu[trial,lvl] - mu_hat[trial, lvl])**2)  *  pi_hat[trial,lvl] -1
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:326: RuntimeWarning: overflow encountered in double_scalars
#   dd = (pi[trial, lvl-1]**-1 + (mu[trial, lvl-1] - mu_hat[trial, lvl-1])**2) * pim_hat -1
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:326: RuntimeWarning: invalid value encountered in double_scalars
#   dd = (pi[trial, lvl-1]**-1 + (mu[trial, lvl-1] - mu_hat[trial, lvl-1])**2) * pim_hat -1
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:320: RuntimeWarning: overflow encountered in exp
#   vv = t[trial] * np.exp(p_dict['ka'][lvl-1]*
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:324: RuntimeWarning: invalid value encountered in double_scalars
#   ww = vv * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:325: RuntimeWarning: invalid value encountered in double_scalars
#   rr = (vv - pi[trial-1, lvl-1]**-1) * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:291: RuntimeWarning: overflow encountered in exp
#   * np.exp(p_dict['ka'][lvl] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:315: RuntimeWarning: invalid value encountered in double_scalars
#   0.5 * pi_hat[trial,lvl]**-1 * \
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:307: RuntimeWarning: overflow encountered in exp
#   v[trial,l-2] = t[trial] * np.exp(p_dict['ka'][l-2] * mu[trial-1, l-1] + p_dict['om'][l-2])
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:308: RuntimeWarning: invalid value encountered in double_scalars
#   w[trial,l-2] = v[trial,l-2] * pi_hat[trial,l-2]
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:344: RuntimeWarning: invalid value encountered in double_scalars
#   da[trial,lvl] = (pi[trial,lvl]**-1 + (mu[trial,lvl] - mu_hat[trial, lvl])**2)  *  pi_hat[trial,lvl] -1
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:398: RuntimeWarning: invalid value encountered in multiply
#   wt[:,1:l]    = np.multiply(0.5 * (v[:,0:l-1] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:320: RuntimeWarning: overflow encountered in exp
#   vv = t[trial] * np.exp(p_dict['ka'][lvl-1]*
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:324: RuntimeWarning: invalid value encountered in double_scalars
#   ww = vv * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:325: RuntimeWarning: invalid value encountered in double_scalars
#   rr = (vv - pi[trial-1, lvl-1]**-1) * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:291: RuntimeWarning: overflow encountered in exp
#   * np.exp(p_dict['ka'][lvl] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:344: RuntimeWarning: invalid value encountered in double_scalars
#   da[trial,lvl] = (pi[trial,lvl]**-1 + (mu[trial,lvl] - mu_hat[trial, lvl])**2)  *  pi_hat[trial,lvl] -1
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:307: RuntimeWarning: overflow encountered in exp
#   v[trial,l-2] = t[trial] * np.exp(p_dict['ka'][l-2] * mu[trial-1, l-1] + p_dict['om'][l-2])
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:308: RuntimeWarning: invalid value encountered in double_scalars
#   w[trial,l-2] = v[trial,l-2] * pi_hat[trial,l-2]
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:315: RuntimeWarning: invalid value encountered in double_scalars
#   0.5 * pi_hat[trial,lvl]**-1 * \
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25.258717
#          Iterations: 17
#          Function evaluations: 1151
#          Gradient evaluations: 127
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [8.39765222 1.         1.        ]
#  sa_0: 	 [0.90064339 0.4990685  0.23674395]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [ 0.71880735 -7.07950583]
#  th: 	 12403.999363554838
#  pi_u: 	 1.8890755689952927
#  al: 	 0.5293594477704517
#
# MODEL QUALITY:
#  LME: 	 -34.78926653594251 		 (more is better)
#  AIC: 	 30.70882248712713 		 (less is better)
#  BIC: 	 31.584175627850065 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:320: RuntimeWarning: overflow encountered in exp
#   vv = t[trial] * np.exp(p_dict['ka'][lvl-1]*
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:324: RuntimeWarning: invalid value encountered in double_scalars
#   ww = vv * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:325: RuntimeWarning: invalid value encountered in double_scalars
#   rr = (vv - pi[trial-1, lvl-1]**-1) * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:291: RuntimeWarning: overflow encountered in exp
#   * np.exp(p_dict['ka'][lvl] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:315: RuntimeWarning: invalid value encountered in double_scalars
#   0.5 * pi_hat[trial,lvl]**-1 * \
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:307: RuntimeWarning: overflow encountered in exp
#   v[trial,l-2] = t[trial] * np.exp(p_dict['ka'][l-2] * mu[trial-1, l-1] + p_dict['om'][l-2])
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:308: RuntimeWarning: invalid value encountered in double_scalars
#   w[trial,l-2] = v[trial,l-2] * pi_hat[trial,l-2]
# Optimization terminated successfully.
#          Current function value: 501.093178
#          Iterations: 34
#          Function evaluations: 360
#          Gradient evaluations: 40
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [10.98865612  1.          1.        ]
#  sa_0: 	 [0.10925788 0.04077824 0.09999802]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [ -3.60774629 -10.55653403]
#  th: 	 0.00033528540521669516
#  pi_u: 	 0.3829658835094703
#  al: 	 2.6111986551806545
#
# MODEL QUALITY:
#  LME: 	 -501.50558591880565 		 (more is better)
#  AIC: 	 992.2280915272172 		 (less is better)
#  BIC: 	 993.2892571042624 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 531.641369
#          Iterations: 32
#          Function evaluations: 396
#          Gradient evaluations: 44
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [10.849064  1.        1.      ]
#  sa_0: 	 [0.04288528 0.0334751  0.10001442]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [ -3.8713374  -10.70464064]
#  th: 	 0.0003357715243538844
#  pi_u: 	 0.22675092535920466
#  al: 	 4.410125332083485
#
# MODEL QUALITY:
#  LME: 	 -532.4293999607847 		 (more is better)
#  AIC: 	 1052.2912791622678 		 (less is better)
#  BIC: 	 1053.2622683364136 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 518.469827
#          Iterations: 37
#          Function evaluations: 378
#          Gradient evaluations: 42
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [9.43465573 1.         1.        ]
#  sa_0: 	 [0.87873771 0.03751018 0.09991218]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [ -3.56378801 -10.59317118]
#  th: 	 0.00033573977032274775
#  pi_u: 	 0.3593970447332423
#  al: 	 2.7824380157111106
#
# MODEL QUALITY:
#  LME: 	 -518.928128721056 		 (more is better)
#  AIC: 	 1026.0281840452471 		 (less is better)
#  BIC: 	 1026.8918920321441 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 536.892859
#          Iterations: 42
#          Function evaluations: 513
#          Gradient evaluations: 57
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [9.83246546 1.         1.        ]
#  sa_0: 	 [0.46108345 0.07415798 0.09998395]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.40222096 -9.60223407]
#  th: 	 0.0003355145077227522
#  pi_u: 	 0.3246636251116396
#  al: 	 3.0801109907404554
#
# MODEL QUALITY:
#  LME: 	 -536.9212864805841 		 (more is better)
#  AIC: 	 1064.023078443507 		 (less is better)
#  BIC: 	 1064.922994437253 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 513.496975
#          Iterations: 34
#          Function evaluations: 369
#          Gradient evaluations: 41
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [10.76386507  1.          1.        ]
#  sa_0: 	 [0.52726507 0.06275878 0.0999915 ]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.93254743 -8.38443329]
#  th: 	 0.0003352306521547163
#  pi_u: 	 0.23336485761506415
#  al: 	 4.28513534651178
#
# MODEL QUALITY:
#  LME: 	 -514.2822778899185 		 (more is better)
#  AIC: 	 1015.0236454782821 		 (less is better)
#  BIC: 	 1016.0709200559716 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 510.313627
#          Iterations: 34
#          Function evaluations: 495
#          Gradient evaluations: 55
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [9.69460122 1.         1.        ]
#  sa_0: 	 [0.27224359 0.0536235  0.10001653]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.8057491  -9.14294776]
#  th: 	 0.00033581365187236123
#  pi_u: 	 0.27653654908555264
#  al: 	 3.6161585269896026
#
# MODEL QUALITY:
#  LME: 	 -511.03897639732025 		 (more is better)
#  AIC: 	 1010.6763522765796 		 (less is better)
#  BIC: 	 1011.6592016518684 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 540.338337
#          Iterations: 36
#          Function evaluations: 387
#          Gradient evaluations: 43
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [9.82616085 1.         1.        ]
#  sa_0: 	 [0.19014288 0.07471834 0.09999594]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.53127588 -8.36335184]
#  th: 	 0.0003353312833135349
#  pi_u: 	 0.2566389436062746
#  al: 	 3.896524767239382
#
# MODEL QUALITY:
#  LME: 	 -541.1256067552592 		 (more is better)
#  AIC: 	 1071.261503433453 		 (less is better)
#  BIC: 	 1072.206418644128 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 530.042065
#          Iterations: 33
#          Function evaluations: 324
#          Gradient evaluations: 36
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [11.61471737  1.          1.        ]
#  sa_0: 	 [0.07417449 0.03904084 0.09993519]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [ -3.82091755 -10.47975622]
#  th: 	 0.0003325130678621668
#  pi_u: 	 0.2411001800238338
#  al: 	 4.147653477078058
#
# MODEL QUALITY:
#  LME: 	 -531.3496704088483 		 (more is better)
#  AIC: 	 1048.9357926460045 		 (less is better)
#  BIC: 	 1050.066575806314 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 540.994158
#          Iterations: 28
#          Function evaluations: 297
#          Gradient evaluations: 33
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [10.06646121  1.          1.        ]
#  sa_0: 	 [0.2382905  0.08454835 0.10010594]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.46264445 -7.56027828]
#  th: 	 0.0003365668438430901
#  pi_u: 	 0.24384435337543767
#  al: 	 4.100976652349783
#
# MODEL QUALITY:
#  LME: 	 -543.817872414713 		 (more is better)
#  AIC: 	 1072.769119770623 		 (less is better)
#  BIC: 	 1073.7678007425045 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
# Optimization terminated successfully.
#          Current function value: 516.980148
#          Iterations: 30
#          Function evaluations: 315
#          Gradient evaluations: 35
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [10.06249948  1.          1.        ]
#  sa_0: 	 [0.17831802 0.05659264 0.09980319]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.99285536 -9.13681477]
#  th: 	 0.00033440117293991826
#  pi_u: 	 0.21709170491417892
#  al: 	 4.606348272935263
#
# MODEL QUALITY:
#  LME: 	 -517.4492858418346 		 (more is better)
#  AIC: 	 1023.9315964294696 		 (less is better)
#  BIC: 	 1024.8861435415804 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 513.407378
#          Iterations: 31
#          Function evaluations: 333
#          Gradient evaluations: 37
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [9.74271604 1.         1.        ]
#  sa_0: 	 [0.48588061 0.03520443 0.09999786]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [ -3.28982695 -10.82961271]
#  th: 	 0.0003359170074439291
#  pi_u: 	 0.49451919820968054
#  al: 	 2.0221661840841034
#
# MODEL QUALITY:
#  LME: 	 -513.7461392220987 		 (more is better)
#  AIC: 	 1016.5018386383272 		 (less is better)
#  BIC: 	 1017.3705672388437 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 484.256820
#          Iterations: 36
#          Function evaluations: 423
#          Gradient evaluations: 47
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [9.50773599 1.         1.        ]
#  sa_0: 	 [0.09243618 0.04685663 0.09999636]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.44160495 -8.89246767]
#  th: 	 0.00033532289416907536
#  pi_u: 	 0.4649238249652888
#  al: 	 2.150889987353649
#
# MODEL QUALITY:
#  LME: 	 -485.29002423221743 		 (more is better)
#  AIC: 	 958.8482567040502 		 (less is better)
#  BIC: 	 959.8676783957452 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:265: RuntimeWarning: overflow encountered in exp
#   pi_hat[trial,0] = (pi[trial-1, 0]**-1 + t[trial] * np.exp(p_dict['ka'][0] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:274: RuntimeWarning: invalid value encountered in double_scalars
#   mu[trial,0] = mu_hat[trial, 0] + pi_hat[trial, 0]**-1 * \
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:296: RuntimeWarning: overflow encountered in exp
#   v[trial, lvl-1] = t[trial] * np.exp(p_dict['ka'][lvl-1] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   w[trial, lvl-1] = v[trial, lvl-1] * pi_hat[trial, lvl-1]
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/scipy/optimize/_numdiff.py:576: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:320: RuntimeWarning: overflow encountered in exp
#   vv = t[trial] * np.exp(p_dict['ka'][lvl-1]*
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:324: RuntimeWarning: invalid value encountered in double_scalars
#   ww = vv * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:325: RuntimeWarning: invalid value encountered in double_scalars
#   rr = (vv - pi[trial-1, lvl-1]**-1) * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:265: RuntimeWarning: overflow encountered in exp
#   pi_hat[trial,0] = (pi[trial-1, 0]**-1 + t[trial] * np.exp(p_dict['ka'][0] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:274: RuntimeWarning: invalid value encountered in double_scalars
#   mu[trial,0] = mu_hat[trial, 0] + pi_hat[trial, 0]**-1 * \
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:296: RuntimeWarning: overflow encountered in exp
#   v[trial, lvl-1] = t[trial] * np.exp(p_dict['ka'][lvl-1] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   w[trial, lvl-1] = v[trial, lvl-1] * pi_hat[trial, lvl-1]
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:291: RuntimeWarning: overflow encountered in exp
#   * np.exp(p_dict['ka'][lvl] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:315: RuntimeWarning: invalid value encountered in double_scalars
#   0.5 * pi_hat[trial,lvl]**-1 * \
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:307: RuntimeWarning: overflow encountered in exp
#   v[trial,l-2] = t[trial] * np.exp(p_dict['ka'][l-2] * mu[trial-1, l-1] + p_dict['om'][l-2])
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:308: RuntimeWarning: invalid value encountered in double_scalars
#   w[trial,l-2] = v[trial,l-2] * pi_hat[trial,l-2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 679.408699
#          Iterations: 1
#          Function evaluations: 104
#          Gradient evaluations: 11
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [10.50007998  1.          1.        ]
#  sa_0: 	 [0.68400602 0.09956517 0.10127054]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-0.35639355 -4.53163265]
#  th: 	 0.0003363907522602121
#  pi_u: 	 3.44901730632684
#  al: 	 0.2899376579426293
#
# MODEL QUALITY:
#  LME: 	 -680.2942103053383 		 (more is better)
#  AIC: 	 1350.6890478085948 		 (less is better)
#  BIC: 	 1351.6827849757194 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 537.010853
#          Iterations: 30
#          Function evaluations: 387
#          Gradient evaluations: 43
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [10.73872561  1.          1.        ]
#  sa_0: 	 [0.46794898 0.0612535  0.09995157]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-2.89775842 -7.36221134]
#  th: 	 0.00033359813716737186
#  pi_u: 	 0.3691944836633385
#  al: 	 2.708599516649011
#
# MODEL QUALITY:
#  LME: 	 -537.7329745060957 		 (more is better)
#  AIC: 	 1064.8108181753414 		 (less is better)
#  BIC: 	 1065.844338684102 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 551.297780
#          Iterations: 32
#          Function evaluations: 351
#          Gradient evaluations: 39
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [10.33349802  1.          1.        ]
#  sa_0: 	 [0.35195234 0.05388263 0.10000183]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [ -3.76659191 -10.11225352]
#  th: 	 0.00033562021632978554
#  pi_u: 	 0.21278717943229675
#  al: 	 4.699531253094943
#
# MODEL QUALITY:
#  LME: 	 -551.3218818225193 		 (more is better)
#  AIC: 	 1091.9392250110013 		 (less is better)
#  BIC: 	 1092.9899747999743 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 522.586271
#          Iterations: 32
#          Function evaluations: 342
#          Gradient evaluations: 38
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [11.09297168  1.          1.        ]
#  sa_0: 	 [0.37221816 0.06845607 0.09999923]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [ -3.04930623 -10.19186838]
#  th: 	 0.0003354563671750647
#  pi_u: 	 0.5167689579683559
#  al: 	 1.9351007535968028
#
# MODEL QUALITY:
#  LME: 	 -523.1736962394457 		 (more is better)
#  AIC: 	 1035.1931244812074 		 (less is better)
#  BIC: 	 1036.2801176006503 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 510.907619
#          Iterations: 42
#          Function evaluations: 513
#          Gradient evaluations: 57
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [9.33767866 1.         1.        ]
#  sa_0: 	 [0.07037452 0.06722012 0.09999965]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.84590199 -8.95661494]
#  th: 	 0.0003357412703520803
#  pi_u: 	 0.25496022358302917
#  al: 	 3.9221804324875196
#
# MODEL QUALITY:
#  LME: 	 -513.0691928291026 		 (more is better)
#  AIC: 	 1011.6085476305151 		 (less is better)
#  BIC: 	 1012.579426923252 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:320: RuntimeWarning: overflow encountered in exp
#   vv = t[trial] * np.exp(p_dict['ka'][lvl-1]*
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:324: RuntimeWarning: invalid value encountered in double_scalars
#   ww = vv * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:325: RuntimeWarning: invalid value encountered in double_scalars
#   rr = (vv - pi[trial-1, lvl-1]**-1) * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:291: RuntimeWarning: overflow encountered in exp
#   * np.exp(p_dict['ka'][lvl] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:315: RuntimeWarning: invalid value encountered in double_scalars
#   0.5 * pi_hat[trial,lvl]**-1 * \
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:307: RuntimeWarning: overflow encountered in exp
#   v[trial,l-2] = t[trial] * np.exp(p_dict['ka'][l-2] * mu[trial-1, l-1] + p_dict['om'][l-2])
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:308: RuntimeWarning: invalid value encountered in double_scalars
#   w[trial,l-2] = v[trial,l-2] * pi_hat[trial,l-2]
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:384: RuntimeWarning: overflow encountered in divide
#   psi[:,1:l]   = np.divide(pi_hat[:,0:l-1], pi[:,1:l])
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:398: RuntimeWarning: invalid value encountered in multiply
#   wt[:,1:l]    = np.multiply(0.5 * (v[:,0:l-1] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:391: RuntimeWarning: overflow encountered in multiply
#   epsi[:,1:l]  = np.multiply(psi[:,1:l], da[:,:l-1])
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:290: RuntimeWarning: overflow encountered in double_scalars
#   pi_hat[trial,lvl] = (pi[trial-1,lvl]**-1 + t[trial]
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:320: RuntimeWarning: overflow encountered in exp
#   vv = t[trial] * np.exp(p_dict['ka'][lvl-1]*
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:324: RuntimeWarning: invalid value encountered in double_scalars
#   ww = vv * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:325: RuntimeWarning: invalid value encountered in double_scalars
#   rr = (vv - pi[trial-1, lvl-1]**-1) * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:291: RuntimeWarning: overflow encountered in exp
#   * np.exp(p_dict['ka'][lvl] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:315: RuntimeWarning: invalid value encountered in double_scalars
#   0.5 * pi_hat[trial,lvl]**-1 * \
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:307: RuntimeWarning: overflow encountered in exp
#   v[trial,l-2] = t[trial] * np.exp(p_dict['ka'][l-2] * mu[trial-1, l-1] + p_dict['om'][l-2])
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:308: RuntimeWarning: invalid value encountered in double_scalars
#   w[trial,l-2] = v[trial,l-2] * pi_hat[trial,l-2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 652.305093
#          Iterations: 1
#          Function evaluations: 454
#          Gradient evaluations: 50
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [9.24997624 1.         1.        ]
#  sa_0: 	 [0.58923465 0.09957828 0.10148149]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-0.50845036 -4.54913958]
#  th: 	 0.0003367512688885
#  pi_u: 	 3.9593894493957755
#  al: 	 0.252564192732444
#
# MODEL QUALITY:
#  LME: 	 -653.0326921723349 		 (more is better)
#  AIC: 	 1296.6326291363312 		 (less is better)
#  BIC: 	 1297.60294792624 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 531.331664
#          Iterations: 32
#          Function evaluations: 324
#          Gradient evaluations: 36
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [10.54150905  1.          1.        ]
#  sa_0: 	 [0.24171104 0.04803633 0.10000247]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.73340026 -9.71335738]
#  th: 	 0.00033564563708957297
#  pi_u: 	 0.25734595655104114
#  al: 	 3.885819747867938
#
# MODEL QUALITY:
#  LME: 	 -531.7883775390866 		 (more is better)
#  AIC: 	 1052.0984672214208 		 (less is better)
#  BIC: 	 1053.0757129803444 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 508.198394
#          Iterations: 33
#          Function evaluations: 360
#          Gradient evaluations: 40
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [11.14379177  1.          1.        ]
#  sa_0: 	 [0.15771147 0.05214284 0.09998634]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.66027501 -9.80234298]
#  th: 	 0.00033681499789263154
#  pi_u: 	 0.3305325980484015
#  al: 	 3.025420203345768
#
# MODEL QUALITY:
#  LME: 	 -508.9450334627835 		 (more is better)
#  AIC: 	 1006.6121669738478 		 (less is better)
#  BIC: 	 1007.6269875954654 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:320: RuntimeWarning: overflow encountered in exp
#   vv = t[trial] * np.exp(p_dict['ka'][lvl-1]*
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:324: RuntimeWarning: invalid value encountered in double_scalars
#   ww = vv * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:325: RuntimeWarning: invalid value encountered in double_scalars
#   rr = (vv - pi[trial-1, lvl-1]**-1) * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:291: RuntimeWarning: overflow encountered in exp
#   * np.exp(p_dict['ka'][lvl] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:315: RuntimeWarning: invalid value encountered in double_scalars
#   0.5 * pi_hat[trial,lvl]**-1 * \
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:307: RuntimeWarning: overflow encountered in exp
#   v[trial,l-2] = t[trial] * np.exp(p_dict['ka'][l-2] * mu[trial-1, l-1] + p_dict['om'][l-2])
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:308: RuntimeWarning: invalid value encountered in double_scalars
#   w[trial,l-2] = v[trial,l-2] * pi_hat[trial,l-2]
# Optimization terminated successfully.
#          Current function value: 510.073660
#          Iterations: 41
#          Function evaluations: 432
#          Gradient evaluations: 48
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [11.33749689  1.          1.        ]
#  sa_0: 	 [0.40348369 0.09487235 0.10000323]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.17841132 -8.5163265 ]
#  th: 	 0.0003356615899253231
#  pi_u: 	 0.4302730612776215
#  al: 	 2.32410552738457
#
# MODEL QUALITY:
#  LME: 	 -510.3743897349214 		 (more is better)
#  AIC: 	 1011.0967751616633 		 (less is better)
#  BIC: 	 1012.2078731275334 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 528.877367
#          Iterations: 23
#          Function evaluations: 288
#          Gradient evaluations: 32
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [11.36453887  1.          1.        ]
#  sa_0: 	 [0.08066975 0.05047074 0.09996807]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.43931103 -7.69282294]
#  th: 	 0.0003342807359402309
#  pi_u: 	 0.28287340900100383
#  al: 	 3.53515024099155
#
# MODEL QUALITY:
#  LME: 	 -530.2527754650034 		 (more is better)
#  AIC: 	 1048.395822235684 		 (less is better)
#  BIC: 	 1049.4202147228632 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 469.203246
#          Iterations: 63
#          Function evaluations: 747
#          Gradient evaluations: 83
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [10.02195706  1.          1.        ]
#  sa_0: 	 [0.42104156 0.0899486  0.09998507]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.31744485 -7.34698742]
#  th: 	 0.0003338738686554085
#  pi_u: 	 0.4333550696936772
#  al: 	 2.307576557733277
#
# MODEL QUALITY:
#  LME: 	 -469.909957003346 		 (more is better)
#  AIC: 	 929.3656047219221 		 (less is better)
#  BIC: 	 930.3418024508162 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 489.360105
#          Iterations: 29
#          Function evaluations: 342
#          Gradient evaluations: 38
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [10.48333221  1.          1.        ]
#  sa_0: 	 [0.09327235 0.04665148 0.09999159]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.46555867 -9.4765056 ]
#  th: 	 0.00033536505664909596
#  pi_u: 	 0.4585326844343762
#  al: 	 2.1808696172521524
#
# MODEL QUALITY:
#  LME: 	 -490.16636986078606 		 (more is better)
#  AIC: 	 969.4455735154129 		 (less is better)
#  BIC: 	 970.3274299379376 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 577.010669
#          Iterations: 32
#          Function evaluations: 387
#          Gradient evaluations: 43
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [11.55130601  1.          1.        ]
#  sa_0: 	 [0.06664839 0.04972849 0.10001825]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [ -3.84362855 -10.02122506]
#  th: 	 0.0003353682024600716
#  pi_u: 	 0.1550811051172557
#  al: 	 6.448238805390942
#
# MODEL QUALITY:
#  LME: 	 -577.6995140393271 		 (more is better)
#  AIC: 	 1143.041311682728 		 (less is better)
#  BIC: 	 1144.168473245897 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 507.397676
#          Iterations: 31
#          Function evaluations: 315
#          Gradient evaluations: 35
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [10.47214359  1.          1.        ]
#  sa_0: 	 [0.16352803 0.04192339 0.0999953 ]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.08317362 -9.41837487]
#  th: 	 0.0003350528040931559
#  pi_u: 	 0.5718997746821494
#  al: 	 1.7485581290109449
#
# MODEL QUALITY:
#  LME: 	 -507.9442757204102 		 (more is better)
#  AIC: 	 1005.4026093097054 		 (less is better)
#  BIC: 	 1006.5003206970813 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 505.576942
#          Iterations: 36
#          Function evaluations: 414
#          Gradient evaluations: 46
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [9.74910558 1.         1.        ]
#  sa_0: 	 [0.22976501 0.14031742 0.10001164]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.55549392 -7.75678638]
#  th: 	 0.00033568870292326826
#  pi_u: 	 0.29105173889216285
#  al: 	 3.435815239607651
#
# MODEL QUALITY:
#  LME: 	 -505.710664242314 		 (more is better)
#  AIC: 	 1001.958282036685 		 (less is better)
#  BIC: 	 1002.8428995069652 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:265: RuntimeWarning: overflow encountered in exp
#   pi_hat[trial,0] = (pi[trial-1, 0]**-1 + t[trial] * np.exp(p_dict['ka'][0] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:274: RuntimeWarning: invalid value encountered in double_scalars
#   mu[trial,0] = mu_hat[trial, 0] + pi_hat[trial, 0]**-1 * \
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:296: RuntimeWarning: overflow encountered in exp
#   v[trial, lvl-1] = t[trial] * np.exp(p_dict['ka'][lvl-1] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   w[trial, lvl-1] = v[trial, lvl-1] * pi_hat[trial, lvl-1]
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/scipy/optimize/_numdiff.py:576: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:320: RuntimeWarning: overflow encountered in exp
#   vv = t[trial] * np.exp(p_dict['ka'][lvl-1]*
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:324: RuntimeWarning: invalid value encountered in double_scalars
#   ww = vv * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:325: RuntimeWarning: invalid value encountered in double_scalars
#   rr = (vv - pi[trial-1, lvl-1]**-1) * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:265: RuntimeWarning: overflow encountered in exp
#   pi_hat[trial,0] = (pi[trial-1, 0]**-1 + t[trial] * np.exp(p_dict['ka'][0] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:274: RuntimeWarning: invalid value encountered in double_scalars
#   mu[trial,0] = mu_hat[trial, 0] + pi_hat[trial, 0]**-1 * \
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:296: RuntimeWarning: overflow encountered in exp
#   v[trial, lvl-1] = t[trial] * np.exp(p_dict['ka'][lvl-1] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   w[trial, lvl-1] = v[trial, lvl-1] * pi_hat[trial, lvl-1]
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:291: RuntimeWarning: overflow encountered in exp
#   * np.exp(p_dict['ka'][lvl] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:315: RuntimeWarning: invalid value encountered in double_scalars
#   0.5 * pi_hat[trial,lvl]**-1 * \
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:307: RuntimeWarning: overflow encountered in exp
#   v[trial,l-2] = t[trial] * np.exp(p_dict['ka'][l-2] * mu[trial-1, l-1] + p_dict['om'][l-2])
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:308: RuntimeWarning: invalid value encountered in double_scalars
#   w[trial,l-2] = v[trial,l-2] * pi_hat[trial,l-2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 656.910895
#          Iterations: 1
#          Function evaluations: 120
#          Gradient evaluations: 13
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [11.16680864  1.          1.        ]
#  sa_0: 	 [0.56589523 0.09937059 0.101542  ]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-0.54216878 -4.69614181]
#  th: 	 0.00033668672729016575
#  pi_u: 	 3.670879109197642
#  al: 	 0.27241431010202183
#
# MODEL QUALITY:
#  LME: 	 -657.7073778619862 		 (more is better)
#  AIC: 	 1305.9019651906417 		 (less is better)
#  BIC: 	 1306.9082454841432 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 528.481179
#          Iterations: 46
#          Function evaluations: 603
#          Gradient evaluations: 67
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [9.37634468 1.         1.        ]
#  sa_0: 	 [0.20870671 0.17098727 0.1000182 ]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.22583667 -7.99755528]
#  th: 	 0.0003354307707536921
#  pi_u: 	 0.31606724197514763
#  al: 	 3.1638837158538244
#
# MODEL QUALITY:
#  LME: 	 -528.920285468678 		 (more is better)
#  AIC: 	 1047.1507655924925 		 (less is better)
#  BIC: 	 1048.0269059295342 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 526.990435
#          Iterations: 31
#          Function evaluations: 324
#          Gradient evaluations: 36
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [11.15443273  1.          1.        ]
#  sa_0: 	 [0.40524761 0.07875332 0.09999984]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [-3.2616243 -8.1509694]
#  th: 	 0.0003355747728037439
#  pi_u: 	 0.3464124885704239
#  al: 	 2.8867319539396603
#
# MODEL QUALITY:
#  LME: 	 -527.3768354151347 		 (more is better)
#  AIC: 	 1044.5988078465134 		 (less is better)
#  BIC: 	 1045.703601489294 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:320: RuntimeWarning: overflow encountered in exp
#   vv = t[trial] * np.exp(p_dict['ka'][lvl-1]*
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:324: RuntimeWarning: invalid value encountered in double_scalars
#   ww = vv * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:325: RuntimeWarning: invalid value encountered in double_scalars
#   rr = (vv - pi[trial-1, lvl-1]**-1) * pim_hat
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:291: RuntimeWarning: overflow encountered in exp
#   * np.exp(p_dict['ka'][lvl] *
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:315: RuntimeWarning: invalid value encountered in double_scalars
#   0.5 * pi_hat[trial,lvl]**-1 * \
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:307: RuntimeWarning: overflow encountered in exp
#   v[trial,l-2] = t[trial] * np.exp(p_dict['ka'][l-2] * mu[trial-1, l-1] + p_dict['om'][l-2])
# /home/jorvhar/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/HGF-0.1.2-py3.8.egg/HGF/hgf.py:308: RuntimeWarning: invalid value encountered in double_scalars
#   w[trial,l-2] = v[trial,l-2] * pi_hat[trial,l-2]
# Optimization terminated successfully.
#          Current function value: 503.327211
#          Iterations: 100
#          Function evaluations: 1062
#          Gradient evaluations: 118
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [9.86511264 1.         1.        ]
#  sa_0: 	 [0.49939478 0.05813296 0.0999831 ]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [ -3.77322954 -10.31524972]
#  th: 	 0.000335747650966798
#  pi_u: 	 0.31608880859969085
#  al: 	 3.1636678452176556
#
# MODEL QUALITY:
#  LME: 	 -503.66437385582157 		 (more is better)
#  AIC: 	 996.537435565737 		 (less is better)
#  BIC: 	 997.4614880949204 		 (less is better)
# Ignored trials: []
#
# Number of levels (depth) inconsistent with length indicated by 'prc_pvec'
#  n_levels: 2
#  prc_pvec depth: 3
#
# ...
#
# Setting new number of levels to 3
# (Make sure no error was made in setting up prc_pvec)
# Ignored trials: []
# Irregular trials: []
#
# Initializing optimization run...
#
# Optimization terminated successfully.
#          Current function value: 548.506900
#          Iterations: 28
#          Function evaluations: 279
#          Gradient evaluations: 31
#
#
# RESULTS:
#
# Parameter estimates - perceptual model:
#  mu_0: 	 [10.02595069  1.          1.        ]
#  sa_0: 	 [0.51442546 0.04561172 0.09989955]
#  rho: 	 [0. 0. 0.]
#  ka: 	 [1. 1.]
#  om: 	 [ -3.44470209 -10.00756611]
#  th: 	 0.00033588153293834293
#  pi_u: 	 0.3020998458601754
#  al: 	 3.3101638868854053
#
# MODEL QUALITY:
#  LME: 	 -548.7927718992772 		 (more is better)
#  AIC: 	 1087.0080891868797 		 (less is better)
#  BIC: 	 1088.0263445791256 		 (less is better)

# %%
# put in dataframe
preddict = pd.DataFrame()

for k in adapt_dict.keys():
    
    tempdict = pd.DataFrame({**surp_dict_flat[blk], **prob_dict_flat[blk]})
    tempdict = tempdict.assign(block=k)
    
    preddict = pd.concat([preddict, tempdict], ignore_index=True)

# %%
preddict
# Out:
#        surp_7.643856189774724  surp_7.664387112768902  surp_7.68491803576308  \
# 0                    5.383890                5.302889               5.222589
# 1                    5.256093                5.175780               5.096175
# 2                    5.095515                5.016320               4.937836
# 3                    6.250935                6.161741               6.073263
# 4                    5.810376                5.724604               5.639551
# ...                       ...                     ...                    ...
# 17275                5.232197                5.144786               5.058205
# 17276                5.100489                5.014315               4.928971
# 17277                5.858716                5.765546               5.673205
# 17278                5.884624                5.791208               5.698623
# 17279                5.508835                5.418788               5.329572
#
#        surp_7.705448958757258  surp_7.725979881751436  surp_7.746510804745614  \
# 0                    5.142991                5.064094                4.985898
# 1                    5.017278                4.939089                4.861608
# 2                    4.860066                4.783009                4.706664
# 3                    5.985502                5.898457                5.812128
# 4                    5.555218                5.471604                5.388708
# ...                       ...                     ...                     ...
# 17275                4.972453                4.887530                4.803436
# 17276                4.844456                4.760770                4.677914
# 17277                5.581694                5.491013                5.401161
# 17278                5.606867                5.515941                5.425845
# 17279                5.241186                5.153631                5.066905
#
#        surp_7.767041727739792  surp_7.78757265073397  surp_7.808103573728148  \
# 0                    4.908403               4.831609                4.755516
# 1                    4.784834               4.708769                4.633411
# 2                    4.631032               4.556113                4.481907
# 3                    5.726516               5.641620                5.557440
# 4                    5.306532               5.225075                5.144337
# ...                       ...                    ...                     ...
# 17275                4.720172               4.637736                4.556129
# 17276                4.595887               4.514690                4.434321
# 17277                5.312139               5.223946                5.136584
# 17278                5.336579               5.248143                5.160537
# 17279                4.981009               4.895944                4.811709
#
#        surp_7.828634496722326  ...  prob_12.38649940142982  \
# 0                    4.680124  ...                0.004997
# 1                    4.558761  ...                0.004054
# 2                    4.408413  ...                0.003225
# 3                    5.473977  ...                0.009295
# 4                    5.064318  ...                0.006102
# ...                       ...  ...                     ...
# 17275                4.475352  ...                0.000854
# 17276                4.354783  ...                0.000727
# 17277                5.050050  ...                0.001703
# 17278                5.073760  ...                0.001744
# 17279                4.728304  ...                0.001158
#
#        prob_12.407030324423998  prob_12.427561247418176  \
# 0                     0.004608                 0.004247
# 1                     0.003730                 0.003430
# 2                     0.002961                 0.002717
# 3                     0.008613                 0.007974
# 4                     0.005631                 0.005193
# ...                        ...                      ...
# 17275                 0.000769                 0.000693
# 17276                 0.000654                 0.000588
# 17277                 0.001543                 0.001397
# 17278                 0.001581                 0.001431
# 17279                 0.001046                 0.000944
#
#        prob_12.448092170412353  prob_12.468623093406531  \
# 0                     0.003911                 0.003599
# 1                     0.003152                 0.002894
# 2                     0.002491                 0.002282
# 3                     0.007378                 0.006821
# 4                     0.004785                 0.004406
# ...                        ...                      ...
# 17275                 0.000623                 0.000560
# 17276                 0.000528                 0.000474
# 17277                 0.001264                 0.001143
# 17278                 0.001295                 0.001171
# 17279                 0.000851                 0.000767
#
#        prob_12.489154016400711  prob_12.509684939394887  \
# 0                     0.003310                 0.003042
# 1                     0.002655                 0.002435
# 2                     0.002089                 0.001911
# 3                     0.006302                 0.005818
# 4                     0.004054                 0.003728
# ...                        ...                      ...
# 17275                 0.000503                 0.000452
# 17276                 0.000425                 0.000381
# 17277                 0.001032                 0.000931
# 17278                 0.001058                 0.000955
# 17279                 0.000691                 0.000621
#
#        prob_12.530215862389065  prob_12.550746785383243  block
# 0                     0.002794                 0.002564    1.0
# 1                     0.002231                 0.002043    1.0
# 2                     0.001747                 0.001596    1.0
# 3                     0.005368                 0.004949    1.0
# 4                     0.003425                 0.003145    1.0
# ...                        ...                      ...    ...
# 17275                 0.000405                 0.000363   36.0
# 17276                 0.000341                 0.000306   36.0
# 17277                 0.000840                 0.000757   36.0
# 17278                 0.000861                 0.000776   36.0
# 17279                 0.000558                 0.000501   36.0
#
# [17280 rows x 481 columns]

# %%
print(stim_df.columns)
plt.plot(stim_df['center_freq_a'])
# Out:
# Index(['frequencies', 'frequencies_oct', 'timing', 'closest_volume_rel',
#        'closest_volume_abs', 'volume_rel', 'volume_abs', 'run', 'block',
#        'segment', 'center_freq_a', 'center_freq_b', 'center_freq_a_oct',
#        'center_freq_b_oct', 'probability_a', 'probability_b'],
#       dtype='object')

# %%
blocks = [5]

f, ax = plt.subplots(figsize=(15, 15))

ax = sns.heatmap(preddict[preddict['block'].isin(blocks)].filter(regex=("prob.*")).T, cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [37], in <cell line: 5>()
#       1 blocks = [5]
#       3 f, ax = plt.subplots(figsize=(15, 15))
# ----> 5 ax = sns.heatmap(preddict[preddict['block'].isin(blocks)].filter(regex=("prob.*")).T, cmap='coolwarm')
#
# NameError: name 'sns' is not defined

# %%
f, ax = plt.subplots(figsize=(15, 15))

ax = sns.heatmap(preddict[preddict['block'].isin(blocks)].filter(regex=("surp.*")).T, cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [38], in <cell line: 3>()
#       1 f, ax = plt.subplots(figsize=(15, 15))
# ----> 3 ax = sns.heatmap(preddict[preddict['block'].isin(blocks)].filter(regex=("surp.*")).T, cmap='coolwarm')
#
# NameError: name 'sns' is not defined

# %%
preddict[preddict['block'].isin([1,2,3])]
# Out:
#       surp_7.643856189774724  surp_7.664387112768902  surp_7.68491803576308  \
# 0                   5.383890                5.302889               5.222589
# 1                   5.256093                5.175780               5.096175
# 2                   5.095515                5.016320               4.937836
# 3                   6.250935                6.161741               6.073263
# 4                   5.810376                5.724604               5.639551
# ...                      ...                     ...                    ...
# 1435                5.232197                5.144786               5.058205
# 17277                 0.001397                 0.001264
# 17278                 0.001431                 0.001295
# 17279                 0.000944                 0.000851
#
#        prob_12.468623093406531  prob_12.489154016400711  \
# 0                     0.003599                 0.003310
# 1                     0.002894                 0.002655
# 2                     0.002282                 0.002089
# 3                     0.006821                 0.006302
# 4                     0.004406                 0.004054
# ...                        ...                      ...
# 17275                 0.000560                 0.000503
# 17276                 0.000474                 0.000425
# 17277                 0.001143                 0.001032
# 17278                 0.001171                 0.001058
# 17279                 0.000767                 0.000691
#
#        prob_12.509684939394887  prob_12.530215862389065  \
# 0                     0.003042                 0.002794
# 1                     0.002435                 0.002231
# 2                     0.001911                 0.001747
# 3                     0.005818                 0.005368
# 4                     0.003728                 0.003425
# ...                        ...                      ...
# 17275                 0.000452                 0.000405
# 17276                 0.000381                 0.000341
# 17277                 0.000931                 0.000840
# 17278                 0.000955                 0.000861
# 17279                 0.000621                 0.000558
#
#        prob_12.550746785383243
# 0                     0.002564
# 1                     0.002043
# 2                     0.001596
# 3                     0.004949
# 4                     0.003145
# ...                        ...
# 17275                 0.000363
# 17276                 0.000306
# 17277                 0.000757
# 17278                 0.000776
# 17279                 0.000501
#
# [17280 rows x 240 columns]

# %% [markdown]
# ## Do the Regression fits

# %%
# take 2000 best voxels and take prefferences and tw
mat1 = scipy.io.loadmat('/media/jorvhar/Data/MRIData/PreProc/S02_SES1/Betas/BetasSEP_AC_denoise0_cv1.mat'.format(pp, pp))
frequenciesmat = scipy.io.loadmat('/media/jorvhar/Data/MRIData/PreProc/S02_SES1/Betas/prfmat_full.mat')
hrf = scipy.io.loadmat('/media/jorvhar/Data/MRIData/PreProc/S02_SES1/Betas/hrf.mat')
con_hrf = [hrf['xdata'][0,:], hrf['ydata'][0,:]]

# settings for nr of best voxels
nrvoxels = 20
bestvoxels = np.argpartition(-mat1['FMapTrain'], nrvoxels)[0, :nrvoxels]

# %%
bestvoxels
# Out:
# array([ 43056,  24760,  59828,  24757,  63673,  47096,  43263,  59718,
#         28370,  39153,  43368,  59827,  63881, 384011,  24758,  32028,
#         43057,  63674,  46887,  43264])

# %%
frequenciesmat['prfpref_full']
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]])

# %%
np.max(bestvoxels)
# Out:
# 401523

# %%
print(mat1.keys())
print(mat1['FMapTrain'][0, bestvoxels])
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'InfoVTCTrain', 'trainSounds', 'FMapTrain', 'BetasSEPTrain', 'InfoVTCTest', 'testSounds', 'BetasSEPTest', 'InfoPRTSEPTrain', 'InfoPRTSEPTest'])
# [5.17720989 5.19823025 5.61848668 ... 4.9799816  4.97931856 4.97606128]

# %%
# subsample highest 2000
plt.hist(mat1['FMapTrain'][0, bestvoxels])

# get all f values
np.random.choice(mat1['FMapTrain'].shape[1], 2000, replace=False)
plt.hist(mat1['FMapTrain'][0, np.random.choice(mat1['FMapTrain'].shape[1], 2000, replace=False)])
# Out:
# (array([3.000e+00, 6.100e+01, 6.940e+02, 1.008e+03, 1.990e+02, 2.500e+01,
#         4.000e+00, 3.000e+00, 2.000e+00, 1.000e+00]),
#  array([-5.48174479, -3.71629034, -1.95083589, -0.18538144,  1.58007301,
#          3.34552746,  5.11098191,  6.87643636,  8.64189081, 10.40734527,
#         12.17279972]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### get frequencie prefferences for our best voxels

# %%
plt.hist(frequenciesmat['prfpref_full'][bestvoxels])
# Out:
# (array([ 36., 166., 119., 165., 284., 503., 580.,  84.,  34.,  29.]),
#  array([ 7.64385619,  8.13454525,  8.62523431,  9.11592337,  9.60661243,
#         10.09730149, 10.58799055, 11.07867961, 11.56936867, 12.06005773,
#         12.55074679]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(frequenciesmat['prftw_full'][bestvoxels])
# Out:
# (array([342., 188., 158., 110.,  81.,  60.,  75.,  76.,  90., 820.]),
#  array([0.74049652, 0.96264548, 1.18479443, 1.40694339, 1.62909235,
#         1.8512413 , 2.07339026, 2.29553921, 2.51768817, 2.73983713,
#         2.96198608]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### fitting

# %%
adaptdict.filter(regex=("acti_.*"))
# Out:
#                                 acti_7.643856189774724  \
# 0    [0.6973480753579487, 0.7171217800348706, 0.254...
# 1    [0.6703706618493117, 0.6914923877603084, 0.218...
# 2    [0.6369523012118541, 0.6596323597570204, 0.180...
# 3    [0.5945840434204855, 0.6190519334948072, 0.138...
# 4    [0.5394080686762059, 0.5658640137709874, 0.095...
# ..                                                 ...
# 355  [0.46540484017154576, 0.49385175334847076, 0.0...
# 356  [0.36353149465728246, 0.39321486904956054, 0.0...
# 357  [0.22394292197632884, 0.25150458653857144, 0.0...
# 358  [0.06294016581085272, 0.07799965568894579, 2.7...
# 359  [6.728132963536085e-05, 0.00014174788318645573...
#
#                                 acti_7.664387112768902  \
# 0    [0.7022421148883378, 0.721953812688135, 0.2575...
# 1    [0.6755923079861912, 0.6966635992240496, 0.222...
# 2    [0.64255080371947, 0.6651987132972952, 0.18316...
# 3    [0.6006116929846945, 0.6250768929938518, 0.141...
# 4    [0.5459068712687272, 0.572408927286468, 0.0979...
# ..                                                 ...
# 355  [0.47236245752356393, 0.5009389967440061, 0.05...
# 356  [0.3707388102633621, 0.4006977858892255, 0.022...
# 357  [0.2305395564047396, 0.2586144076932011, 0.003...
# 358  [0.0664094858534266, 0.08212368159385978, 3.02...
# 359  [8.106593565386859e-05, 0.00016952823579471641...
#
#                                  acti_7.68491803576308  \
# 0    [0.7071220560269387, 0.7267686129147496, 0.261...
# 1    [0.6808028793377121, 0.7018201380429415, 0.225...
# 2    [0.6481429501481463, 0.6707545362388305, 0.186...
# 3    [0.6066405054711407, 0.6310981311570023, 0.144...
# 4    [0.5524191605103822, 0.5789616156614531, 0.100...
# ..                                                 ...
# 355  [0.4793544043224972, 0.5080540925724262, 0.057...
# 356  [0.37801631327129265, 0.40824458591999513, 0.0...
# 357  [0.23726302248430312, 0.2658496028068158, 0.00...
# 358  [0.07003321885751809, 0.08642031999014856, 3.3...
# 359  [9.749656605147333e-05, 0.0002023832607555833,...
#
#                                 acti_7.705448958757258  \
# 0    [0.7119871298734219, 0.7315654039085042, 0.264...
# 1    [0.6860014953930275, 0.7069611088848499, 0.228...
# 2    [0.6537277222802784, 0.6762987841499547, 0.189...
# 4    [0.3465223171671566, 0.3247239612976086, 0.922...
# ..                                                 ...
# 355  [0.2689685740719064, 0.2481642826932796, 0.905...
# 356  [0.1759941256929893, 0.15821340646766746, 0.87...
# 357  [0.07660480919415164, 0.0654417825202018, 0.82...
# 358  [0.008667402351618649, 0.006478445547911677, 0...
# 359  [6.869826828226836e-08, 2.4992705240658732e-08...
#
#                                acti_12.530215862389065  \
# 0    [0.5335876720161888, 0.5135791727570328, 0.951...
# 1    [0.498136276740787, 0.47745569282746275, 0.946...
# 2    [0.4556693791849683, 0.43439030108792387, 0.93...
# 3    [0.40416542385727505, 0.3824898650398913, 0.93...
# 4    [0.34108083179196214, 0.3194726176695917, 0.91...
# ..                                                 ...
# 355  [0.26374510203573226, 0.24320130544998964, 0.9...
# 356  [0.1714865427129378, 0.1540409381087697, 0.870...
# 357  [0.07372129024089383, 0.06290580244266245, 0.8...
# 358  [0.008074066195872599, 0.006022095670138904, 0...
# 359  [5.369934239745628e-08, 1.9391797676966004e-08...
#
#                                acti_12.550746785383243
# 0    [0.5286423243832428, 0.5086777993438876, 0.949...
# 1    [0.49301679003151294, 0.47240298614853043, 0.9...
# 2    [0.4503910242327023, 0.42920906842759976, 0.93...
# 3    [0.3987740188654037, 0.3772362834894144, 0.927...
# 4    [0.3356854113850513, 0.3142693264732436, 0.914...
# ..                                                 ...
# 355  [0.2585854810174534, 0.23830293927818139, 0.89...
# 356  [0.16706227750911298, 0.14994966805386117, 0.8...
# 357  [0.07092613796259108, 0.06045090206141107, 0.8...
# 358  [0.007517395307118811, 0.005594950172589098, 0...
# 359  [4.189857290822024e-08, 1.5018617659376736e-08...
#
# [360 rows x 240 columns]

# %%
blocks = [5]

f, ax = plt.subplots(figsize=(15, 15))

ax = sns.heatmap(adaptdict[adaptdict['block'].isin(blocks)].filter(regex=("acti.*")).T, cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [54], in <cell line: 5>()
#       1 blocks = [5]
#       3 f, ax = plt.subplots(figsize=(15, 15))
# ----> 5 ax = sns.heatmap(adaptdict[adaptdict['block'].isin(blocks)].filter(regex=("acti.*")).T, cmap='coolwarm')
#
# NameError: name 'sns' is not defined

# %%
plt.plot(act_dict[blk][7.643856189774724][2.480493528013555])
plt.plot(adapt_dict[blk][7.643856189774724][2.480493528013555])
plt.plot(surp_dict[blk][7.643856189774724])
plt.plot(prob_dict[blk][7.643856189774724])

# %%
plt.plot(  scipy.stats.zscore(act_dict[blk][7.643856189774724][2.480493528013555])  )
plt.plot(  scipy.stats.zscore(adapt_dict[blk][7.643856189774724][2.480493528013555])  )
plt.plot(  scipy.stats.zscore(surp_dict[blk][7.643856189774724])  )
plt.plot(  scipy.stats.zscore(prob_dict[blk][7.643856189774724])  )

# %%
acti = np.array([])
adap = np.array([])
pred = np.array([])
surp = np.array([])

for blk in act_dict.keys():
    acti.append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [57], in <cell line: 6>()
#       4 surp = np.array([])
#       6 for blk in act_dict.keys():
# ----> 7     acti.append()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %% [markdown]
# ### HRF things

# %%
def normalize(data):
    return (data - np.min(data)) / (np.max(data) - np.min(data))

def find_padding(tr, ntrials, tlen):
    padding = 0
    notdiv = int(ntrials*tlen*10) % int(tr*10)
    while notdiv != 0:
        padding += 1
        newlen = ntrials + padding
        # check if modulated by 10 is whole number 
        if (newlen*tlen*10).is_integer():
            notdiv = int(newlen*tlen*10) % int(tr*10)
        if padding > 100000: 
            raise Exception("Sorry, padding not possible") 
    return(padding)

# %%
# hrf and stim lengts
trialleng = stim_df['timing'].diff()[1]
con_hrf_vollen = np.diff(con_hrf[0])[0]

# interpolate
xnew = np.arange(np.min(con_hrf[0]), np.max(con_hrf[0]), trialleng)
f = scipy.interpolate.interp1d(con_hrf[0], con_hrf[1], kind='cubic')
newhrf = normalize(f(xnew))
plt.plot(normalize(f(xnew)))

# %%
newhrf
# Out:
# array([7.62557974e-02, 6.17848366e-02, 7.32559754e-02, 1.07165660e-01,
#        1.60010335e-01, 2.28286449e-01, 3.08490445e-01, 3.97118772e-01,
#        4.90667873e-01, 5.85634196e-01, 6.78514186e-01, 7.65804289e-01,
#        8.44000952e-01, 9.09600620e-01, 9.59099739e-01, 9.89217183e-01,
#        1.00000000e+00, 9.94057274e-01, 9.74063995e-01, 9.42695150e-01,
#        9.02625728e-01, 8.56530718e-01, 8.07064020e-01, 7.56059735e-01,
#        7.04287011e-01, 6.52443828e-01, 6.01228162e-01, 5.51337990e-01,
#        5.03471292e-01, 4.58324948e-01, 4.16363584e-01, 3.77533634e-01,
#        3.41711415e-01, 3.08773244e-01, 2.78595441e-01, 2.51054321e-01,
#        2.26026204e-01, 2.03375580e-01, 1.82919640e-01, 1.64463746e-01,
#        1.47813263e-01, 1.32773553e-01, 1.19149981e-01, 1.06747910e-01,
#        9.53837050e-02, 8.49550450e-02, 7.53960522e-02, 6.66410209e-02,
#        5.86242457e-02, 5.12800210e-02, 4.45426413e-02, 3.83483808e-02,
#        3.26631392e-02, 2.74756215e-02, 2.27751195e-02, 1.85509250e-02,
#        1.47923296e-02, 1.14886251e-02, 8.62907964e-03, 6.20203983e-03,
#        4.19465560e-03, 2.59399686e-03, 1.38713352e-03, 5.61135503e-04,
#        1.03072703e-04, 0.00000000e+00, 2.35784563e-04, 7.87181376e-04,
#        1.62998310e-03, 2.73998238e-03, 4.09297188e-03, 5.66474426e-03,
#        7.43109218e-03, 9.36812283e-03, 1.14532016e-02, 1.36640083e-02,
#        1.59782229e-02, 1.83735252e-02, 2.08275953e-02, 2.33181128e-02,
#        2.58236359e-02, 2.83292121e-02, 3.08227975e-02, 3.32923619e-02,
#        3.57258754e-02, 3.81113077e-02, 4.04366287e-02, 4.26901524e-02,
#        4.48653423e-02, 4.69596257e-02, 4.89705321e-02, 5.08955907e-02,
#        5.27323309e-02, 5.44782821e-02, 5.61310270e-02, 5.76902208e-02,
#        5.91582112e-02, 6.05375259e-02, 6.18306924e-02, 6.30402384e-02,
#        6.41686916e-02, 6.52185809e-02, 6.61927601e-02, 6.70948065e-02,
#        6.79283952e-02, 6.86972018e-02, 6.94049013e-02, 7.00551691e-02,
#        7.06516806e-02, 7.11980085e-02, 7.16973162e-02, 7.21526646e-02,
#        7.25671147e-02, 7.29437273e-02, 7.32855634e-02, 7.35956839e-02,
#        7.38770378e-02, 7.41317470e-02, 7.43615628e-02, 7.45682347e-02,
#        7.47535122e-02, 7.49191447e-02, 7.50668817e-02, 7.51984728e-02,
#        7.53156674e-02, 7.54202150e-02, 7.55138650e-02, 7.55983671e-02,
#        7.56754706e-02, 7.57469251e-02])

# %%
newpadding = find_padding(1.8, 480, 0.25)


xpredz_dict = {}

for blk in act_dict.keys():
    
    xpredz_dict[blk] = {}
    
    for frq in act_dict[blk].keys():
        
        xpredz_dict[blk][frq] = {}
        
        for tw in act_dict[blk][frq].keys():
            
    
            xpredz = np.empty([4, 480])

            xpredz[0, :] = scipy.stats.zscore(act_dict[blk][frq][tw])
            xpredz[1, :] = scipy.stats.zscore(adapt_dict[blk][frq][tw])
            xpredz[2, :] = scipy.stats.zscore(surp_dict[blk][frq])
            xpredz[3, :] = scipy.stats.zscore(prob_dict[blk][frq])

            xpredz = np.nan_to_num(xpredz)
            
            # make dimensions match up
            xpredz = np.pad(xpredz, [(0, 0), (0, newpadding)], mode='constant')

            # then convolve and resample
            convoled = scipy.signal.convolve(xpredz, np.tile(newhrf, (4, 1)), mode='same')
            resampled_convolved = np.transpose(scipy.signal.resample(np.transpose(convoled), int((convoled.shape[1]*0.25)/1.8)))

            # save in dict
            xpredz_dict[blk][frq][tw] = resampled_convolved

# %%
xpredz_dict[1].keys()
xpredz_dict[1][7.643856189774724].keys()
# Out:
# dict_keys([2.480493528013555, 2.3549626459296964, 2.2174591221797617, 2.0654560287347112, 1.895531027292399, 1.702885949350003, 1.4804935280135552, 1.2174591221797617, 0.8955310272923991, 0.48049352801355516])

# %%
plt.plot(scipy.signal.resample(np.transpose(resampled_convolved), int((convoled.shape[1]*0.25)/1.8)))
# Out:
# [<matplotlib.lines.Line2D at 0x7fdc50d1edc0>,
#  <matplotlib.lines.Line2D at 0x7fdc50d1ee80>,
#  <matplotlib.lines.Line2D at 0x7fdc50d1ee50>,
#  <matplotlib.lines.Line2D at 0x7fdc47b960a0>]

# %%
plt.plot(scipy.signal.resample(np.transpose(xpredz_dict[1][7.643856189774724][1.4804935280135552]), int((convoled.shape[1]*0.25)/1.8)))
# Out:
# [<matplotlib.lines.Line2D at 0x7fdc47b004c0>,
#  <matplotlib.lines.Line2D at 0x7fdc47b00520>,
#  <matplotlib.lines.Line2D at 0x7fdc47b00640>,
#  <matplotlib.lines.Line2D at 0x7fdc47b00760>]

# %%
stim_df.keys()
# Out:
# Index(['frequencies', 'frequencies_oct', 'timing', 'closest_volume_rel',
#        'closest_volume_abs', 'volume_rel', 'volume_abs', 'run', 'block',
#        'segment', 'center_freq_a', 'center_freq_b', 'center_freq_a_oct',
#        'center_freq_b_oct', 'probability_a', 'probability_b'],
#       dtype='object')

# %%
rundict = {}
volumes=240

# FULL RUN DICTIONARY


for currun in stim_df['run'].unique():
    
    rundict[currun] = {}
    
    for frq in act_dict[1].keys():

        rundict[currun][frq] = {}

        for tw in act_dict[blk][frq].keys():

 
    

            runarray = np.zeros([4, volumes])

            for blk in stim_df['block'][stim_df['run'] == currun].unique():

                startidx = stim_df['volume_rel'][stim_df['block'] == blk].to_numpy()[0]
                temparray = xpredz_dict[blk][frq][tw]

                runarray[:, startidx:startidx+temparray.shape[1]] = temparray

            rundict[currun][frq][tw] = runarray

# %%
# FULL EXP DICTIONARY


fullpred = {}

for frq in act_dict[1].keys():

    fullpred[frq] = {}

    for tw in act_dict[blk][frq].keys():
            
        fullpred[frq][tw] = np.concatenate([rundict[x][frq][tw] for x in rundict], 1)

# %%
plt.plot(np.transpose(fullpred[7.643856189774724][1.4804935280135552][:, :245]))
# Out:
# [<matplotlib.lines.Line2D at 0x7fdc47b1c2b0>,
#  <matplotlib.lines.Line2D at 0x7fdc476f9a30>,
#  <matplotlib.lines.Line2D at 0x7fdc476f9b50>,
#  <matplotlib.lines.Line2D at 0x7fdc476f9c70>]

# %%
plt.plot(np.transpose(rundict[1][7.643856189774724][1.4804935280135552]))
# Out:
# [<matplotlib.lines.Line2D at 0x7fdc47661a60>,
#  <matplotlib.lines.Line2D at 0x7fdc47661ac0>,
#  <matplotlib.lines.Line2D at 0x7fdc47661be0>,
#  <matplotlib.lines.Line2D at 0x7fdc47661d00>]

# %%
# get predictions for some tw and some tpref over complete exp
plt.plot(np.transpose(fullpred[7.643856189774724][1.4804935280135552]))
# Out:
# [<matplotlib.lines.Line2D at 0x7fdc475cf340>,
#  <matplotlib.lines.Line2D at 0x7fdc475cf3a0>,
#  <matplotlib.lines.Line2D at 0x7fdc475cf4c0>,
#  <matplotlib.lines.Line2D at 0x7fdc475cf5e0>]

# %%
# get predictions for some tw and some tpref over run
plt.plot(np.transpose(rundict[4][7.643856189774724][1.4804935280135552]))
# Out:
# [<matplotlib.lines.Line2D at 0x7fdc475b5d90>,
#  <matplotlib.lines.Line2D at 0x7fdc475b5df0>,
#  <matplotlib.lines.Line2D at 0x7fdc475b5f10>,
#  <matplotlib.lines.Line2D at 0x7fdc47542070>]

# %% [markdown]
# ## linear reg

# %%
frequenciesmat['prfpref_full'][:,0][bestvoxels]
# Out:
# array([10.55924725,  9.67641757, 10.21022156,  9.67641757, 10.78508741,
#        10.10756695, 10.04597418, 10.00491233,  9.43004649, 10.04597418,
#        10.08703603, 10.04597418, 10.0665051 , 10.39499987,  9.7996031 ,
#         9.90225772,  9.75854126, 10.3334071 , 10.62084002, 10.02544326])

# %%
frequenciesmat['prftw_full'][:,0][bestvoxels]
# Out:
# array([1.72782521, 2.96198608, 2.46832174, 2.96198608, 1.23416087,
#        2.96198608, 2.96198608, 2.96198608, 2.96198608, 2.96198608,
#        2.96198608, 2.96198608, 2.96198608, 2.96198608, 2.96198608,
#        2.96198608, 2.96198608, 2.96198608, 0.98732869, 2.96198608])

# %%
mskimg # all the y's
# Out:
# array([[8.41547775e+00, 1.05983324e+01, 9.55021763e+00, ...,
#         2.85954418e+01, 3.06347122e+01, 2.02062988e+01],
#        [1.76596882e-06, 2.52842983e-06, 3.58289526e-06, ...,
#         9.24846902e-03, 2.29047276e-02, 2.45497692e-02],
#        [4.98420288e+02, 5.21224060e+02, 5.23294678e+02, ...,
#         5.12017151e+02, 4.69779480e+02, 4.94555725e+02],
#        ...,
#        [3.60374146e+02, 3.04346069e+02, 3.36199768e+02, ...,
#         3.03543549e+02, 3.03131805e+02, 3.11229980e+02],
#        [1.01662415e+02, 9.79953079e+01, 1.28016220e+02, ...,
#         1.40178101e+02, 1.24102768e+02, 1.06994476e+02],
#        [1.97048294e+02, 1.95620255e+02, 2.28101608e+02, ...,
#         1.81169952e+02, 1.57241852e+02, 1.57694244e+02]])

# %%
tw = octgrid[0]
frq = muarray[-25]

tw, frq
# Out:
# (2.480493528013555, 12.058004633522973)

# %%
# sellect from 20 voxels
vox = 4

# get predictors
curtun = frequenciesmat['prfpref_full'][:,0][bestvoxels][vox]
curtw = frequenciesmat['prftw_full'][:,0][bestvoxels][vox]

tunidx = np.where(np.abs(np.array(list(fullpred.keys())) - curtun) < 0.001)
tunidx = list(fullpred.keys())[tunidx[0][0]]
twidx = np.where(np.abs(np.array(list(fullpred[tunidx].keys())) - curtw) < 0.5)
twidx = list(fullpred[tunidx].keys())[twidx[0][0]]

x = np.transpose(fullpred[tunidx][twidx])

# %%
y = mskimg[vox]

# %%
# y = np.mean(x, axis=1)
# y += np.random.normal(0,5,y.shape[0])

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn import svm
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.75, test_size=0.25, random_state=0)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((2160, 4), (2160,), (720, 4), (720,))

# %%
# Create linear regression object
regr = LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# The coefficients
print("Coefficients: \n", regr.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))

# other info
print(f'\n\nIntercept at {regr.intercept_}')
print(f'Coefficents are {regr.coef_}')
# Out:
# Coefficients:
#  [-1.03298153  0.12682434 -0.43126034  0.24186266]
# Mean squared error: 1828.89
# Coefficient of determination: -0.00
#
#
# Intercept at 148.13034240260652
# Coefficents are [-1.03298153  0.12682434 -0.43126034  0.24186266]

# %%
# do kfold check
folds = KFold(n_splits = 4, shuffle = True, random_state = 100)
scores = cross_val_score(regr, X_train, y_train, scoring='r2', cv=folds)

scores
# Out:
# array([ 3.59339565e-03, -5.52758433e-03, -1.10634010e-02, -7.02513466e-05])

# %%
octgrid[-2], muarray[100]
# Out:
# (0.8955310272923991, 9.696948489192515)

# %%
tw, frq
# Out:
# (2.480493528013555, 12.058004633522973)

# %%
np.transpose(fullpred[frq][tw])[:,0]



blk = 7
tw = octgrid[0]
frq = muarray[-25]

plt.figure(figsize=(16, 8))

cfs = regr.coef_

# activation
line, = plt.plot( cfs[0] * np.transpose(fullpred[frq][tw])[firstpulse:firstpulse+70,0], lw=4)
line.set_color('#50514F')

# adaptation
line, = plt.plot( cfs[1] * np.transpose(fullpred[frq][tw])[firstpulse:firstpulse+70,1], lw=4)
line.set_color('#F25F5C')

# surprisal
line, = plt.plot( cfs[2] * np.transpose(fullpred[frq][tw])[firstpulse:firstpulse+70,2], lw=4)
line.set_color('#247BA0')

# probability
line, = plt.plot( cfs[3] * np.transpose(fullpred[frq][tw])[firstpulse:firstpulse+70,3], lw=4)
line.set_color('#70C1B3')

# %%
np.sum(cfs * np.transpose(fullpred[frq][tw])[firstpulse:firstpulse+70,:], axis=1)
# Out:
# array([-0.93288801, -4.16804396, -5.84445559, -5.10033384, -3.73303802,
#        -2.53095007, -2.15402172, -1.21789718, -0.51260526, -2.11837279,
#        -2.42681998, -2.55946154, -1.8276269 , -1.54693124, -2.17373602,
#        -2.19381464, -1.49483468,  1.51904698,  3.09013271,  2.98450271,
#         4.30920842,  4.24147664,  3.95742656,  3.49487969,  3.33516971,
#         2.84743888,  2.30071581,  1.786576  , -0.21941749, -1.23355394,
#        -1.56148629, -1.63659053, -1.55602175, -2.07759716, -0.36153829,
#         3.91789463,  5.03305564,  4.66200775,  4.66621865,  3.77539401,
#         2.74227482,  2.61010393,  2.72500981,  3.50479487,  3.50765422,
#         1.56462699,  0.64540018,  1.61013851,  0.6754169 ,  1.14476451,
#         2.02009259,  2.41289579,  1.89754737,  2.56778775,  3.52191043,
#         3.32939116,  2.09685534,  1.30622419,  0.57410562,  0.51198075,
#         0.01088709,  0.22431121,  0.03179728,  0.53295179, -0.37341239,
#         0.        ,  0.        ,  0.        ,  0.        ,  0.        ])

# %%
np.transpose(fullpred[frq][tw])[:,0]



blk = 5
tw = octgrid[-2]
frq = muarray[100]

plt.figure(figsize=(16, 8))

cfs = regr.coef_

fullpres = cfs 

# activation
line, = plt.plot(np.sum(cfs * np.transpose(fullpred[frq][tw])[firstpulse:firstpulse+70,:], axis=1), lw=4)
line.set_color('#50514F')

# %%
plt.figure(figsize=(16, 8))

firstpulse = stim_df['volume_abs'][stim_df['block'] == 5].to_numpy()[0]
plt.plot(y[firstpulse:firstpulse+70], lw=4, color='#DEC687')

# %%
plt.figure(figsize=(16, 8))

firstpulse = stim_df['volume_abs'][stim_df['block'] == 5].to_numpy()[0]
plt.plot(y[firstpulse:firstpulse+70], lw=4, color='#DEC687')

# %%
## now actually
import bvbabel
from os.path import join, exists, split

# %%
betasep = scipy.io.loadmat('/media/jorvhar/Data/MRIData/PreProc/S02_SES1/Betas/BetasSEP_AC_denoise0_cv1.mat')
_, temp = bvbabel.vtc.read_vtc('/media/jorvhar/Data/MRIData/PreProc/S02_SES1/S02_SES1_run1_FMR_SCSTBL_3DMCTS_THPGLMF7c_TOPUP.vtc')

# %%
homedir = '/media/jorvhar/Data/MRIData/PreProc/S02_SES2'

vtclist = []
for i in np.arange(1,13):
    vtclist.append(f'S02_SES2_run{i}_FMR_SCSTBL_3DMCTS_THPGLMF7c_TOPUP.vtc')


vtc_dict = {}
for i in range(len(vtclist)):
    vtc_dict[i+1] = bvbabel.vtc.read_vtc(join(homedir, vtclist[i]))

# %%
plt.imshow(vtc_dict[1][1][:,:,20,5])

# %%
temp.shape[0:-1]
t_xyz = (temp.shape[0], temp.shape[1], temp.shape[2])

# %%
run = 1

## IMPORTATN CODE, MATLAB LIN INDEX TO PYTHON
npidx = np.unravel_index(betasep['InfoVTCTrain']['voxVTC'][0][0][:, 0], t_xyz, 'F')
# C', 'F', 'A', or 'K'

maskedimg = np.zeros([temp.shape[0], temp.shape[1], temp.shape[2], vtc_dict[1][1].shape[-1]])
maskedimg[:vtc_dict[1][1].shape[0],
          :vtc_dict[1][1].shape[1],
          :vtc_dict[1][1].shape[2],
          :] =                           vtc_dict[run][1]

# %%
maskedimg[npidx][bestvoxels]
# Out:
# (20, 240)

# %%
mskimg=[]
for run in vtc_dict.keys():

    ## IMPORTATN CODE, MATLAB LIN INDEX TO PYTHON
    npidx = np.unravel_index(betasep['InfoVTCTrain']['voxVTC'][0][0][:, 0], t_xyz, 'F')
    # C', 'F', 'A', or 'K'

    maskedimg = np.zeros([temp.shape[0], temp.shape[1], temp.shape[2], vtc_dict[1][1].shape[-1]])
    maskedimg[:vtc_dict[1][1].shape[0],
              :vtc_dict[1][1].shape[1],
              :vtc_dict[1][1].shape[2],
              :] =                           vtc_dict[run][1]


    try:
        mskimg = np.concatenate( (mskimg, maskedimg[npidx][bestvoxels]), axis=1)
        
    except:
        
        mskimg = maskedimg[npidx][bestvoxels]
        
        

    #maskedim2 = np.zeros(maskedimg.shape)
    #maskedim2[npidx] = maskedimg[npidx]
    #plt.imshow()

# %%
mskimg.shape
# Out:
# (20, 2880)

# %%
np.concatenate( (maskedimg[npidx], maskedimg[npidx]), axis=1).shape
# Out:
# (408605, 480)

# %%
plt.imshow(maskedim2[:,:,10,50])

# %%
maskedimg[npidx]
# Out:
# (408605, 240)

# %%
masked_img = np.squeeze(maskedimg[npidx], axis=1)
xyzt = maskedimg.shape

recreate_img_matlab(npidx, masked_img, xyzt)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [285], in <cell line: 1>()
# ----> 1 masked_img = np.squeeze(maskedimg[npidx], axis=1)
#       2 xyzt = maskedimg.shape
#       4 recreate_img_matlab(npidx, masked_img, xyzt)
#
# File <__array_function__ internals>:180, in squeeze(*args, **kwargs)
#
# File ~/miniconda3/envs/bv_preproc/lib/python3.8/site-packages/numpy/core/fromnumeric.py:1545, in squeeze(a, axis)
#    1543     return squeeze()
#    1544 else:
# -> 1545     return squeeze(axis=axis)
#
# ValueError: cannot select an axis to squeeze out which has size not equal to one

# %%
betasep['InfoVTCTrain']['voxVTC'][0][0][:,0]
# Out:
# array([ 209268,  209292,  209293, ..., 2285157, 2285158, 2285159],
#       dtype=int32)

# %%
def recreate_img_matlab(img, mskimg, xyzt):
    """input masked image, image mask and original xyz(t) list of dimension values
    returns reconstructed image in orignal space"""
    # create empty array in original shape
    re_img = np.zeros(xyzt)
    re_img[mskimg] = img
    return(re_img)

# %%
npidx
# Out:
# (array([[190],
#         [  0],
#         [  1],
#         ...,
#         [ 65],
#         [ 66],
#         [ 67]]),
#  array([[101],
#         [102],
#         [102],
#         ...,
#         [166],
#         [166],
#         [166]]),
#  array([[ 4],
#         [ 4],
#         [ 4],
#         ...,
#         [48],
#         [48],
#         [48]]))

# %%
plt.imshow(maskedimg[npidx])

# %%
_, temp = bvbabel.vtc.read_vtc('/media/jorvhar/Data/MRIData/PreProc/S02_SES1/S02_SES1_run1_FMR_SCSTBL_3DMCTS_THPGLMF7c_TOPUP.vtc')
temp.shape

# %%
temp.shape

# %%
temp[np.where(mskimg)].shape

# %%
mask_fn = '/media/jorvhar/Data/MRIData/PreProc/S02_SES1/AC2.msk'

_, mskimg = read_msk(mask_fn)

mskimg = mskimg[:213, :219, :52]
mskimg.shape

# %%
img = vtc_dict[1][1][np.where(mskimg)]
img.shape

# %%
mskimg.shape

# %%
vtc_dict[1][1].shape

# %%
"""Read, write, create Brainvoyager MSK file format."""

import struct
import numpy as np

def recreate_img(img, mskimg, xyzt):
    """input masked image, image mask and original xyz(t) list of dimension values
    returns reconstructed image in orignal space"""
    # create empty array in original shape
    re_img = np.zeros(xyzt)
    re_img[np.where(mskimg)] = img
    return(re_img)

# =============================================================================
def read_msk(filename):
    """Read Brainvoyager MSK file.

    Parameters
    ----------
    filename : string
        Path to file.

    Returns
    -------
    header : dictionary
        Pre-data header.
    data : 3D numpy.array
        Image data.

    """
    header = dict()
    with open(filename, 'rb') as f:
        
        # Expected binary data: short int (2 bytes)
        data, = struct.unpack('<h', f.read(2))
        header["VTC resolution relative to VMR (1, 2, or 3)"] = data
        
        # Expected binary data: short int (2 bytes)
        data, = struct.unpack('<h', f.read(2))
        header["XStart"] = data
        data, = struct.unpack('<h', f.read(2))
        header["XEnd"] = data
        data, = struct.unpack('<h', f.read(2))
        header["YStart"] = data
        data, = struct.unpack('<h', f.read(2))
        header["YEnd"] = data
        data, = struct.unpack('<h', f.read(2))
        header["ZStart"] = data
        data, = struct.unpack('<h', f.read(2))
        header["ZEnd"] = data

        # Prepare dimensions of VTC data array
        VTC_resolution = header["VTC resolution relative to VMR (1, 2, or 3)"]
        DimX = (header["XEnd"] - header["XStart"]) // VTC_resolution
        DimY = (header["YEnd"] - header["YStart"]) // VTC_resolution
        DimZ = (header["ZEnd"] - header["ZStart"]) // VTC_resolution
        
        # ---------------------------------------------------------------------
        # Read MSK data
        # ---------------------------------------------------------------------
        
        data_img = np.zeros(DimZ * DimY * DimX)
        
        for i in range(data_img.size):
            data_img[i], = struct.unpack('<B', f.read(1))
        
        data_img = np.reshape(data_img, (DimZ, DimY, DimX))
        data_img = np.transpose(data_img, (0, 2, 1))  # BV to Tal
        data_img = data_img[::-1, ::-1, ::-1]  # Flip BV axes

    return header, data_img


# =============================================================================
def write_msk(filename, header, data_img):
    """Protocol to write Brainvoyager MSK file.

    Parameters
    ----------
    filename : string
        Path to file.
    header : dictionary
        Pre-data header.
    data_img : 3D numpy.array
        Image data.

    """
    with open(filename, 'wb') as f:

        # Expected binary data: short int (2 bytes)
        data = header["VTC resolution relative to VMR (1, 2, or 3)"]
        f.write(struct.pack('<h', data))

        data = header["XStart"]
        f.write(struct.pack('<h', data))
        data = header["XEnd"]
        f.write(struct.pack('<h', data))
        data = header["YStart"]
        f.write(struct.pack('<h', data))
        data = header["YEnd"]
        f.write(struct.pack('<h', data))
        data = header["ZStart"]
        f.write(struct.pack('<h', data))
        data = header["ZEnd"]
        f.write(struct.pack('<h', data))

        # ---------------------------------------------------------------------
        # Write MSK data
        # ---------------------------------------------------------------------
        data_img = data_img[::-1, ::-1, ::-1]  # Flip BV axes
        data_img = np.transpose(data_img, (0, 2, 1))  # Tal to BV
        data_img = np.reshape(data_img, data_img.size)

        for i in range(data_img.size):
            f.write(struct.pack('<B', int(data_img[i])))
